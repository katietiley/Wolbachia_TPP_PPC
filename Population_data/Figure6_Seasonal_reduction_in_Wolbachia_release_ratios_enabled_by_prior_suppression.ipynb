# %% [markdown]
# # Figure 6. Reduction in Wolbachia RR enabled by prior suppression with seasonality
# Author: Katie Tiley (katherine.tiley@lshtm.ac.uk) <br>
# Date: 05 Dec 22 <br>
# <br>
# Note: in the code RIDL refers to 1gSLT, and IIT refers to Male Wolbachia release

# %%
from scipy.integrate import odeint
import numpy as np
import matplotlib as mat
import matplotlib.pyplot as plt
from scipy import integrate as sp
import seaborn as sns
from tabulate import tabulate
import pandas as pd
import statsmodels.api as sm
import json
from decimal import Decimal as dec
import time
import os

# %%
filepath = os.path.abspath(os.getcwd())

# %% [markdown]
# ### 1. Set up model
# Parameters:

# %%
# MOSQUITO
alphaO = 0.5  # rate that eggs hatch into larvae
alphaL = 0.18  # rate that larvae pupate
alphaP = 1  # rate that pupae eclose
phi = 500*(1/14)    # number eggs laid per mosquito per day
muO = 0.01    # daily death rate of eggs
muL = 0.1*alphaL    # daily death rate of larvae
muP = 0.1*alphaP     # pupae death rate
muM = 1/14     # adult mosquito death rate
muF = 1/14     # adult female mosquito death rate

# density-dependence via Bellows 1981:
AA = 1   # determines the density at which mortality remains proportionate
BB = 0.5   # determines the 'abruptness' of density-dependence

# WOLBACHIA
fCI = 0.012   # prop of cytoplasmic incompatibility that fails 'sigma'
MT = 0    # prop of wolbachia females that don't successfully maternally transfer 'omega'
c = 0.5    # mating competitiveness of released wolbachia males
cv = 1    # coverage of adulticide
e = 1.2    # relative mortality of wolbachia adults compared to wild adults
RR = 1    # release ratio of wolbachia eggs to wild type eggs
RRsupp = 1    # release ratio of wolbachia eggs to wild type eggs for suppression techniques

# %% [markdown]
# Initial conditions:
# (equilibrium values previously defined in Supp)

# %%
O0 = 15947.608023052446
OW0 = 0
rOW0 = 0
OS0 = 0
L0 = 40271.71074193975
LW0 = 0
rLW0 = 0
LS0 = 0
P0 = 32.67541200187585
PW0 = 0
rPW0 = 0
PS0 = 0
M0 = 228.72754035145144
MW0 = 0
MS0 = 0
F0 = 228.72754035145144
FW0 = 0

# %% [markdown]
# Seasonal precipitation function:

# %%
SA = 2.09    # brings seasonal population average to match non-seasonal model so functions still apply

with open("Rio.json", 'r') as f: # import precipitation data
    score = json.load(f)  

def K(t):
    return (score[round(t)])*SA

# %% [markdown]
# Wolbachia release function:

# %%
start_wol = 200

def pulseN(t, start_wol=start_wol, releasenumber=5, frequency=14):    
    for i in range(0,releasenumber,1):
        if round(t) == start_wol + (frequency*i):
            return 0 #O0
    else:
        return 0

# %% [markdown]
# Suppression functions:

# %%
# IIT

def IIT(t, releasenumber=1, frequency=7, end=start_wol):
    for i in range(0,releasenumber,1):
        if round(t) == (end-frequency) - (frequency*i):
            return 0 #M0+F0
    else:
        return 0

# %%
# SIT / RIDL

switch = 0 #0 for SIT; 1 for RIDL

def SIT(t, releasenumber=1, frequency=7, end=start_wol):    
    for i in range(0,releasenumber,1):
        if round(t) == (end-frequency) - (frequency*i):
            return 0 #M0+F0
    else:
        return 0

# %%
# Environmental management

start_em = 193
stop_em = 200
em_eff = 1 #0.526

def em(t):
    if round(t) < start_em:     #start
        return 1
    elif round(t) > stop_em:    #stop releases
        return 1
    else:
        return em_eff

# %%
# Larvicides (e.g. guppies)

start_lv = 193
stop_lv = 200
lv_eff = 1 #5.95

def lv(t):
    if round(t) < start_lv:     #start
        return 1
    elif round(t) > stop_lv:    #stop releases
        return 1
    else:
        return lv_eff

# %%
# Adulticide

h = start_wol

def ad(t):    
    ad_eff = 0 #4.9 #0.455
    if round(t) < h:
        return 0
    elif round(t) > h+0.01:
        return 0
    else:
        return ad_eff

# %% [markdown]
# Model:

# %%
def deriv(y, t, fCI, MT, c, e, phi, alphaO, muO, AA, BB, alphaL, alphaP, muP, muM, muF, RR, RRsupp, pulseN, K, IIT, SIT, em, lv, ad, cv, switch):
    
    O, OW, rOW, OS, L, LW, rLW, LS, P, PW, rPW, PS, M, MW, MS, F, FW = y
    
    #MOSQUITOES
    
    allfemales = 1+F+FW
    allmales = 1+M+MW+(MS*c)
    
    F_nothing = F + FW*MT 
    M_nothing = M + MW*fCI 
    
    F_wol = FW*(1-MT)
    
    #Eggs
    dOdt = em(t) * phi * F_nothing * M_nothing/allmales - alphaO*O - lv(t)*muO*O # eggs laid * females no-wol * (males no_wol / all males) (aka prop no-wol males)
    dOWdt = em(t) * phi * F_wol * (M+MW)/allmales - alphaO*OW - lv(t)*muO*OW 
    drOWdt = pulseN(t)*RR - alphaO*rOW - muO*rOW
    dOSdt = phi * allfemales * (MS*c)/allmales - alphaO*OS - muO*OS
    
    #Larvae
    dLdt =  alphaO*O - alphaL*L - lv(t)*muL*L
    dLWdt = alphaO*OW - alphaL*LW - lv(t)*muL*LW
    drLWdt = alphaO*rOW - alphaL*rLW - muL*rLW
    dLSdt = switch*alphaO*OS - alphaL*LS - muL*LS
    
    #Pupae 
    dPdt =  alphaL*(L/(1+((AA*K(t)*(L+LW+LS))**BB))) - alphaP*P - lv(t)*muP*P 
    dPWdt = alphaL*(LW/(1+((AA*K(t)*(L+LW+LS))**BB))) - alphaP*PW - lv(t)*muP*PW
    drPWdt = alphaL*(rLW/(1+((AA*(rLW))**BB))) - alphaP*rPW - muP*rPW 
    dPSdt = alphaL*(LS/(1+((AA*K(t)*(L+LW+LS))**BB))) - alphaP*PS - muP*PS
        
    #Adult
    dMdt =  .5*alphaP*P - muM*M - ad(t)*M*cv
    dMWdt = IIT(t)*RRsupp + .5*alphaP*(PW+rPW) - muM*e*MW - ad(t)*MW*cv
    dMSdt = SIT(t)*RRsupp + .5*alphaP*PS - muM*e*MS
    
    dFdt =  .5*alphaP*P - muF*F - ad(t)*F*cv
    dFWdt = .5*alphaP*(PW+rPW) - muF*e*FW - ad(t)*FW*cv

    return dOdt, dOWdt, drOWdt, dOSdt, dLdt, dLWdt, drLWdt, dLSdt, dPdt, dPWdt, drPWdt, dPSdt, dMdt, dMWdt, dMSdt, dFdt, dFWdt

# %% [markdown]
# Model prerequisites:

# %%
t = np.linspace(0, 1500, 1501) # grid of time points (in days)
y0 = O0, OW0, rOW0, OS0, L0, LW0, rLW0, LS0, P0, PW0, rPW0, PS0, M0, MW0, MS0, F0, FW0 # initial condition vector

# %% [markdown]
# Run model:

# %%
ret = odeint(deriv, y0, t,args=(fCI, MT, c, e, phi, alphaO, muO, AA, BB, alphaL, alphaP, muP, muM, muF, RR, RRsupp, pulseN, K, IIT, SIT, em, lv, ad, cv, switch),hmax=1)

O, OW, rOW, OS, L, LW, rLW, LS, P, PW, rPW, PS, M, MW, MS, F, FW = ret.T

# %% [markdown]
# Visual check all suppression functions are off and seasonality is effective: (should see cyclic population)

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=[10,10])

ax1.plot(t, F+FW+M+MW, 'blue', label='all adults')
ax1.plot(t, F+FW, 'pink', label='all females')
ax1.set_xlabel("Time (days)",fontsize=12, labelpad=8)
ax1.set_ylabel("Number of Adult Mosquitoes",fontsize=12, labelpad=8)
ax1.legend()

ax2.plot(t, M+F, 'black', label='all wildtypes')
ax2.plot(t, MW+FW, 'red', label='all wol')
ax2.set_xlabel("Time (days)",fontsize=12, labelpad=8)
ax2.set_ylabel("Number of wildtype and wol mosquitoes",fontsize=12, labelpad=8)
ax2.legend()

ax3.plot(t, L, 'black', linestyle='dashed', label='wildtype larvae')
ax3.plot(t, P, 'black', label='wildtype pupae')
ax3.plot(t, LW, 'grey', linestyle='dashed', label='wol larvae')
ax3.plot(t, PW, 'grey', label='wol pupae')
ax3.set_xlabel("Time (days)",fontsize=12, labelpad=8)
ax3.set_ylabel("Number of wildtype and wol \naquatic stage mosquitoes",fontsize=12, labelpad=8)
ax3.legend()

ax4.plot(t[140:400], (MW[140:400]+FW[140:400])/(MW[140:400]+FW[140:400]+M[140:400]+F[140:400]), 'black')
plt.xticks([150,200,250,300,350,400])
ax4.set_xlabel("Time (days)",fontsize=12, labelpad=8)
ax4.set_ylabel("Proportion of Mosquitoes with Wolbachia", fontsize=12, labelpad=8)


plt.subplots_adjust(wspace=.35)

#plt.savefig('wolAedesDemo-KT', dpi=300, facecolor='w', edgecolor='w',
#        orientation='portrait', format=None, transparent=False, bbox_inches=None, pad_inches=0.1, metadata=None)

# %%
# baseline seasonality population dynamics

O_base = O
L_base = L
P_base = P
M_base = M
F_base = F

# %% [markdown]
# Convert raw eggRR values into adultRR values:

# %%
RR_df = pd.read_csv(f'{filepath}/adultRR_eggRR_df.csv')

def convert_RR(RR):
    return  list(RR_df.loc[RR_df['eggRR'] == RR]['adultRR'])[0]

# %%
RR_df
# Out:
#      adultRR   eggRR
# 0     0.0025  0.0005
# 1     0.0050  0.0010
# 2     0.0075  0.0015
# 3     0.0100  0.0020
# 4     0.0125  0.0025
# ..       ...     ...
# 195   0.4900  2.3630
# 196   0.4925  2.3870
# 197   0.4950  2.4115
# 198   0.4975  2.4360
# 199   0.5000  2.4605
#
# [200 rows x 2 columns]

# %% [markdown]
# ### 2.a. Data collection: minimum Wolbachia RR with each suppression for fixation within 6 months
# ### No suppression:

# %%
start_time = time.time()




RR_vec = list(RR_df.iloc[:,1])
nosupp_RR = [] #capture results here
start_wol = 0
eggRR = 0
x = 0


while start_wol < 722:

    
    start_wol = start_wol+7
    x = x+1 # index for storing results
    zoo = [] # shell capturing within-loop results
    loop_start_time = time.time()
    
    def pulseN(t, start_wol=start_wol, releasenumber=5, frequency=14):    
        for i in range(0,releasenumber,1):
            if round(t) == start_wol + (frequency*i):
                return O0
        else:
            return 0
    
    
    if eggRR == 0: # search whole RR vec
        a = 0
        b = 199
    else: # search only within range of last RR
        idx = list(RR_df.index[RR_df['eggRR'] == eggRR])
        
        if idx[0]-15 < 1: #if lower boundary crosses 0 set as 0
            a = 0
        else:
            a = idx[0]-15
        
        if idx[0]+15 > 199: #if upper boundary crosses max set as max
            b = 199
        else:
            b = idx[0]+15
        
    
    for i in RR_vec[a:b]:
        
        RR = i
                
        # run the model
        t = np.linspace(0, 1500, 1501) # grid of time points (in days)
        y0 = O0, OW0, rOW0, OS0, L0, LW0, rLW0, LS0, P0, PW0, rPW0, PS0, M0, MW0, MS0, F0, FW0 # initial condition vector
        ret = odeint(deriv, y0, t,args=(fCI, MT, c, e, phi, alphaO, muO, AA, BB, alphaL, alphaP, muP, muM, muF, RR, RRsupp, pulseN, K, IIT, SIT, em, lv, ad, cv, switch),hmax=1)
        O, OW, rOW, OS, L, LW, rLW, LS, P, PW, rPW, PS, M, MW, MS, F, FW = ret.T

        # get output
        total = MW+FW+M+F
        prop = (MW+FW)/(MW+FW+M+F)
    
        # find fixation points
        fix = np.argwhere(prop > 0.95)
        if sum(fix) > 0:
            min_fix = min(fix)-start_wol
            min_fix = min_fix.tolist()
        else:
            min_fix = 0 #occurs if no fixation
        
        zoo.append(min_fix) #store fixation points
        
        
    # flatten list
    flat_list = []
    for sublist in zoo:
        if type(sublist) == list:
            for item in sublist:
                flat_list.append(item)
        else:
            flat_list.append(sublist)
    
    
    # only keep fix within 6 months
    sixm_list2 = [] 
    for i in flat_list:
        if (i >= 182.5) == True: #within 6 months
            i = 0
        sixm_list2.append(i)
    
    
    # convert eggRR to adultRR and store result outside of loop
    if sum(sixm_list2) > 0: 
        ind = (sixm_list2.index(max(sixm_list2)))
        eggRR = RR_vec[ind+a]
        adultRR = convert_RR(eggRR)
        nosupp_RR.append(adultRR)
    else:
        eggRR = 0
        nosupp_RR.append('NaN')

    print("Loop ",x,", start wol:", start_wol)
    current_time = time.time()
    elapsed_time = current_time - loop_start_time
    print('processing time:',round(elapsed_time/60,2),'minutes')
        

print("Kernel complete")
current_time = time.time()
elapsed_time = current_time - start_time
print('processing time:',round(elapsed_time/60,2),'minutes')
# Out:
# Loop  1 , start wol: 7
# processing time: 8.23 minutes
# Loop  2 , start wol: 14
# processing time: 1.23 minutes
# Loop  3 , start wol: 21
# processing time: 1.23 minutes
# Loop  4 , start wol: 28
# processing time: 4.91 minutes
# Loop  5 , start wol: 35
# processing time: 1.23 minutes
# Loop  6 , start wol: 42
# processing time: 1.23 minutes
# Loop  7 , start wol: 49
# processing time: 1.23 minutes
# Loop  8 , start wol: 56
# processing time: 1.24 minutes
# Loop  9 , start wol: 63
# processing time: 1.24 minutes
# Loop  10 , start wol: 70
# processing time: 1.25 minutes
# Loop  11 , start wol: 77
# processing time: 1.24 minutes
# Loop  12 , start wol: 84
# processing time: 1.24 minutes
# Loop  13 , start wol: 91
# processing time: 1.24 minutes
# Loop  14 , start wol: 98
# processing time: 1.24 minutes
# Loop  15 , start wol: 105
# processing time: 1.24 minutes
# Loop  16 , start wol: 112
# processing time: 1.24 minutes
# Loop  17 , start wol: 119
# processing time: 1.24 minutes
# Loop  18 , start wol: 126
# processing time: 1.24 minutes
# Loop  19 , start wol: 133
# processing time: 1.24 minutes
# Loop  20 , start wol: 140
# processing time: 1.24 minutes
# Loop  21 , start wol: 147
# processing time: 1.24 minutes
# Loop  22 , start wol: 154
# processing time: 1.25 minutes
# Loop  23 , start wol: 161
# processing time: 1.24 minutes
# Loop  24 , start wol: 168
# processing time: 1.24 minutes
# Loop  25 , start wol: 175
# processing time: 1.24 minutes
# Loop  26 , start wol: 182
# processing time: 1.25 minutes
# Loop  27 , start wol: 189
# processing time: 1.24 minutes
# Loop  28 , start wol: 196
# processing time: 1.24 minutes
# Loop  29 , start wol: 203
# processing time: 1.24 minutes
# Loop  30 , start wol: 210
# processing time: 1.24 minutes
# Loop  31 , start wol: 217
# processing time: 1.24 minutes
# Loop  32 , start wol: 224
# processing time: 1.24 minutes
# Loop  33 , start wol: 231
# processing time: 1.24 minutes
# Loop  34 , start wol: 238
# processing time: 1.24 minutes
# Loop  35 , start wol: 245
# processing time: 1.24 minutes
# Loop  36 , start wol: 252
# processing time: 1.24 minutes
# Loop  37 , start wol: 259
# processing time: 1.24 minutes
# Loop  38 , start wol: 266
# processing time: 1.24 minutes
# Loop  39 , start wol: 273
# processing time: 1.24 minutes
# Loop  40 , start wol: 280
# processing time: 1.24 minutes
# Loop  41 , start wol: 287
# processing time: 1.24 minutes
# Loop  42 , start wol: 294
# processing time: 1.25 minutes
# Loop  43 , start wol: 301
# processing time: 1.24 minutes
# Loop  44 , start wol: 308
# processing time: 1.25 minutes
# Loop  45 , start wol: 315
# processing time: 1.24 minutes
# Loop  46 , start wol: 322
# processing time: 1.25 minutes
# Loop  47 , start wol: 329
# processing time: 1.25 minutes
# Loop  48 , start wol: 336
# processing time: 1.25 minutes
# Loop  49 , start wol: 343
# processing time: 1.24 minutes
# Loop  50 , start wol: 350
# processing time: 1.25 minutes
# Loop  51 , start wol: 357
# processing time: 1.25 minutes
# Loop  52 , start wol: 364
# processing time: 1.25 minutes
# Loop  53 , start wol: 371
# processing time: 1.25 minutes
# Loop  54 , start wol: 378
# processing time: 1.25 minutes
# Loop  55 , start wol: 385
# processing time: 1.25 minutes
# Loop  56 , start wol: 392
# processing time: 1.24 minutes
# Loop  57 , start wol: 399
# processing time: 1.25 minutes
# Loop  58 , start wol: 406
# processing time: 1.24 minutes
# Loop  59 , start wol: 413
# processing time: 1.24 minutes
# Loop  60 , start wol: 420
# processing time: 1.25 minutes
# Loop  61 , start wol: 427
# processing time: 1.25 minutes
# Loop  62 , start wol: 434
# processing time: 1.24 minutes
# Loop  63 , start wol: 441
# processing time: 1.25 minutes
# Loop  64 , start wol: 448
# processing time: 1.25 minutes
# Loop  65 , start wol: 455
# processing time: 1.24 minutes
# Loop  66 , start wol: 462
# processing time: 1.25 minutes
# Loop  67 , start wol: 469
# processing time: 1.25 minutes
# Loop  68 , start wol: 476
# processing time: 1.24 minutes
# Loop  69 , start wol: 483
# processing time: 1.25 minutes
# Loop  70 , start wol: 490
# processing time: 1.24 minutes
# Loop  71 , start wol: 497
# processing time: 1.25 minutes
# Loop  72 , start wol: 504
# processing time: 1.25 minutes
# Loop  73 , start wol: 511
# processing time: 1.25 minutes
# Loop  74 , start wol: 518
# processing time: 1.25 minutes
# Loop  75 , start wol: 525
# processing time: 1.25 minutes
# Loop  76 , start wol: 532
# processing time: 1.24 minutes
# Loop  77 , start wol: 539
# processing time: 1.25 minutes
# Loop  78 , start wol: 546
# processing time: 1.25 minutes
# Loop  79 , start wol: 553
# processing time: 1.24 minutes
# Loop  80 , start wol: 560
# processing time: 1.24 minutes
# Loop  81 , start wol: 567
# processing time: 1.24 minutes
# Loop  82 , start wol: 574
# processing time: 1.24 minutes
# Loop  83 , start wol: 581
# processing time: 1.24 minutes
# Loop  84 , start wol: 588
# processing time: 1.24 minutes
# Loop  85 , start wol: 595
# processing time: 1.24 minutes
# Loop  86 , start wol: 602
# processing time: 1.24 minutes
# Loop  87 , start wol: 609
# processing time: 1.24 minutes
# Loop  88 , start wol: 616
# processing time: 1.25 minutes
# Loop  89 , start wol: 623
# processing time: 1.25 minutes
# Loop  90 , start wol: 630
# processing time: 1.25 minutes
# Loop  91 , start wol: 637
# processing time: 1.24 minutes
# Loop  92 , start wol: 644
# processing time: 1.24 minutes
# Loop  93 , start wol: 651
# processing time: 1.24 minutes
# Loop  94 , start wol: 658
# processing time: 1.25 minutes
# Loop  95 , start wol: 665
# processing time: 1.25 minutes
# Loop  96 , start wol: 672
# processing time: 1.24 minutes
# Loop  97 , start wol: 679
# processing time: 1.24 minutes
# Loop  98 , start wol: 686
# processing time: 1.25 minutes
# Loop  99 , start wol: 693
# processing time: 1.24 minutes
# Loop  100 , start wol: 700
# processing time: 1.25 minutes
# Loop  101 , start wol: 707
# processing time: 1.25 minutes
# Loop  102 , start wol: 714
# processing time: 1.24 minutes
# Loop  103 , start wol: 721
# processing time: 1.25 minutes
# Loop  104 , start wol: 728
# processing time: 1.25 minutes
# Kernel complete
# processing time: 139.98 minutes

# %%
nosupp_RR
# Out:
# [0.2075,
#  0.21,
#  0.21,
#  0.2075,
#  0.2,
#  0.1925,
#  0.185,
#  0.175,
#  0.165,
#  0.155,
#  0.145,
#  0.1375,
#  0.13,
#  0.1225,
#  0.115,
#  0.11,
#  0.1025,
#  0.1,
#  0.095,
#  0.0925,
#  0.0875,
#  0.0875,
#  0.085,
#  0.0825,
#  0.0825,
#  0.0825,
#  0.0825,
#  0.0825,
#  0.0825,
#  0.0825,
#  0.085,
#  0.0875,
#  0.09,
#  0.0925,
#  0.095,
#  0.1,
#  0.105,
#  0.11,
#  0.1175,
#  0.1225,
#  0.13,
#  0.14,
#  0.15,
#  0.16,
#  0.17,
#  0.1825,
#  0.195,
#  0.205,
#  0.215,
#  0.225,
#  0.2325,
#  0.2375,
#  0.2375,
#  0.235,
#  0.23,
#  0.2225,
#  0.215,
#  0.205,
#  0.1925,
#  0.1825,
#  0.17,
#  0.16,
#  0.15,
#  0.14,
#  0.1325,
#  0.125,
#  0.1175,
#  0.11,
#  0.105,
#  0.1,
#  0.095,
#  0.0925,
#  0.09,
#  0.0875,
#  0.085,
#  0.0825,
#  0.0825,
#  0.0825,
#  0.0825,
#  0.0825,
#  0.0825,
#  0.0825,
#  0.085,
#  0.0875,
#  0.09,
#  0.0925,
#  0.095,
#  0.1,
#  0.105,
#  0.11,
#  0.115,
#  0.1225,
#  0.13,
#  0.1375,
#  0.1475,
#  0.1575,
#  0.17,
#  0.18,
#  0.1925,
#  0.2025,
#  0.215,
#  0.225,
#  0.23,
#  0.235]

# %%
len(nosupp_RR) # check 104 timepoints, two years sampled weekly
# Out:
# 104

# %%
data = {'nosupp_RR': nosupp_RR}

nosupp_RR_df = pd.DataFrame(data)
nosupp_RR_df.to_csv('nosupp_RR.csv')

# %% [markdown]
# ### IIT

# %%
IIT_df = pd.read_csv(f'{filepath}/IIT_df_01-02-24.csv')
RRsupp = list(IIT_df.loc[IIT_df['Target efficacy'] == 65, 'RRsupp value'])
RRsupp = RRsupp[0]

# %%
start_time = time.time()




RR_vec = list(RR_df.iloc[:,1])
IIT_RR = [] #capture results here
start_wol = 0
eggRR = 0
x = -1


while start_wol < 722:

    
    start_wol = start_wol+7
    x = x+1 # index for storing results
    zoo = [] # shell capturing within-loop results
    
    
    def pulseN(t, start_wol=start_wol, releasenumber=5, frequency=14):    
        for i in range(0,releasenumber,1):
            if round(t) == start_wol + (frequency*i):
                return O0
        else:
            return 0
    
    def IIT(t, releasenumber=5, frequency=7, end=start_wol):
        for i in range(0,releasenumber,1):
            if round(t) == (end-frequency) - (frequency*i):
                return M0+F0
        else:
            return 0
    
    if eggRR == 0: # search whole RR vec
        a = 0
        b = 199
    else: # search only within range of last RR
        idx = list(RR_df.index[RR_df['eggRR'] == eggRR])
        
        if idx[0]-15 < 0: #if lower boundary crosses 0 set as 0
            a = 0
        else:
            a = idx[0]-15
        
        if idx[0]+15 > 199: #if upper boundary crosses max set as max
            b = 199
        else:
            b = idx[0]+15
        
    
    for i in RR_vec[a:b]:
        
        RR = i
        
        # run the model
        t = np.linspace(0, 1500, 1501) # Grid of time points (in days)
        y0 = O0, OW0, rOW0, OS0, L0, LW0, rLW0, LS0, P0, PW0, rPW0, PS0, M0, MW0, MS0, F0, FW0 # Init condition vector
        ret= odeint(deriv, y0, t,args=(fCI, MT, c, e, phi, alphaO, muO, AA, BB, alphaL, alphaP, muP, muM, muF, RR, RRsupp, pulseN, K, IIT, SIT, em, lv, ad, cv, switch),hmax=1)
        O, OW, rOW, OS, L, LW, rLW, LS, P, PW, rPW, PS, M, MW, MS, F, FW = ret.T

        # get output
        total = MW+FW+M+F
        prop = (MW+FW)/(MW+FW+M+F)
    
        # find fixation points
        fix = np.argwhere(prop > 0.95)
        if sum(fix) > 0:
            min_fix = min(fix)-start_wol
            min_fix = min_fix.tolist()
        else:
            min_fix = 0 #occurs if no fixation
        
        zoo.append(min_fix) #store fixation points
        
    
    # flatten list
    flat_list = []
    for sublist in zoo:
        if type(sublist) == list:
            for item in sublist:
                flat_list.append(item)
        else:
            flat_list.append(sublist)
    
    
    # only keep fix within 6 months
    sixm_list2 = [] 
    for i in flat_list:
        if (i >= 182.5) == True: #within 6 months
            i = 0
        sixm_list2.append(i)
    
    
    # convert eggRR to adultRR and store result outside of loop
    if sum(sixm_list2) > 0: 
        ind = (sixm_list2.index(max(sixm_list2)))
        eggRR = RR_vec[ind+a]
        adultRR = convert_RR(eggRR)
        IIT_RR.append(adultRR)
    else:
        eggRR = 0
        IIT_RR.append('NaN')
        
        
    print("Loop ",x,", start wol:", start_wol)
    current_time = time.time()
    elapsed_time = current_time - start_time
    print('processing time:',round(elapsed_time/60,2),'minutes')
    
    
    
print("Kernel complete")   
current_time = time.time()
elapsed_time = current_time - start_time
print('processing time:',round(elapsed_time/60,2),'minutes')
# Out:
# Loop  0 , start wol: 7
# processing time: 8.71 minutes
# Loop  1 , start wol: 14
# processing time: 10.02 minutes
# Loop  2 , start wol: 21
# processing time: 11.36 minutes
# Loop  3 , start wol: 28
# processing time: 12.68 minutes
# Loop  4 , start wol: 35
# processing time: 13.99 minutes
# Loop  5 , start wol: 42
# processing time: 15.32 minutes
# Loop  6 , start wol: 49
# processing time: 16.63 minutes
# Loop  7 , start wol: 56
# processing time: 17.93 minutes
# Loop  8 , start wol: 63
# processing time: 19.27 minutes
# Loop  9 , start wol: 70
# processing time: 20.61 minutes
# Loop  10 , start wol: 77
# processing time: 21.93 minutes
# Loop  11 , start wol: 84
# processing time: 23.27 minutes
# Loop  12 , start wol: 91
# processing time: 24.6 minutes
# Loop  13 , start wol: 98
# processing time: 25.87 minutes
# Loop  14 , start wol: 105
# processing time: 27.05 minutes
# Loop  15 , start wol: 112
# processing time: 28.2 minutes
# Loop  16 , start wol: 119
# processing time: 29.33 minutes
# Loop  17 , start wol: 126
# processing time: 30.36 minutes
# Loop  18 , start wol: 133
# processing time: 31.3 minutes
# Loop  19 , start wol: 140
# processing time: 32.2 minutes
# Loop  20 , start wol: 147
# processing time: 33.0 minutes
# Loop  21 , start wol: 154
# processing time: 33.79 minutes
# Loop  22 , start wol: 161
# processing time: 34.53 minutes
# Loop  23 , start wol: 168
# processing time: 35.23 minutes
# Loop  24 , start wol: 175
# processing time: 35.93 minutes
# Loop  25 , start wol: 182
# processing time: 36.63 minutes
# Loop  26 , start wol: 189
# processing time: 37.33 minutes
# Loop  27 , start wol: 196
# processing time: 37.99 minutes
# Loop  28 , start wol: 203
# processing time: 38.65 minutes
# Loop  29 , start wol: 210
# processing time: 39.32 minutes
# Loop  30 , start wol: 217
# processing time: 39.98 minutes
# Loop  31 , start wol: 224
# processing time: 40.64 minutes
# Loop  32 , start wol: 231
# processing time: 41.3 minutes
# Loop  33 , start wol: 238
# processing time: 41.96 minutes
# Loop  34 , start wol: 245
# processing time: 42.62 minutes
# Loop  35 , start wol: 252
# processing time: 43.28 minutes
# Loop  36 , start wol: 259
# processing time: 43.93 minutes
# Loop  37 , start wol: 266
# processing time: 44.63 minutes
# Loop  38 , start wol: 273
# processing time: 45.33 minutes
# Loop  39 , start wol: 280
# processing time: 46.03 minutes
# Loop  40 , start wol: 287
# processing time: 46.74 minutes
# Loop  41 , start wol: 294
# processing time: 47.5 minutes
# Loop  42 , start wol: 301
# processing time: 48.25 minutes
# Loop  43 , start wol: 308
# processing time: 49.05 minutes
# Loop  44 , start wol: 315
# processing time: 49.89 minutes
# Loop  45 , start wol: 322
# processing time: 50.82 minutes
# Loop  46 , start wol: 329
# processing time: 51.83 minutes
# Loop  47 , start wol: 336
# processing time: 52.95 minutes
# Loop  48 , start wol: 343
# processing time: 54.14 minutes
# Loop  49 , start wol: 350
# processing time: 55.43 minutes
# Loop  50 , start wol: 357
# processing time: 56.77 minutes
# Loop  51 , start wol: 364
# processing time: 58.11 minutes
# Loop  52 , start wol: 371
# processing time: 59.45 minutes
# Loop  53 , start wol: 378
# processing time: 60.79 minutes
# Loop  54 , start wol: 385
# processing time: 62.14 minutes
# Loop  55 , start wol: 392
# processing time: 63.48 minutes
# Loop  56 , start wol: 399
# processing time: 64.81 minutes
# Loop  57 , start wol: 406
# processing time: 66.14 minutes
# Loop  58 , start wol: 413
# processing time: 67.5 minutes
# Loop  59 , start wol: 420
# processing time: 68.81 minutes
# Loop  60 , start wol: 427
# processing time: 70.14 minutes
# Loop  61 , start wol: 434
# processing time: 71.47 minutes
# Loop  62 , start wol: 441
# processing time: 72.78 minutes
# Loop  63 , start wol: 448
# processing time: 74.09 minutes
# Loop  64 , start wol: 455
# processing time: 75.4 minutes
# Loop  65 , start wol: 462
# processing time: 76.71 minutes
# Loop  66 , start wol: 469
# processing time: 77.94 minutes
# Loop  67 , start wol: 476
# processing time: 79.12 minutes
# Loop  68 , start wol: 483
# processing time: 80.21 minutes
# Loop  69 , start wol: 490
# processing time: 81.27 minutes
# Loop  70 , start wol: 497
# processing time: 82.24 minutes
# Loop  71 , start wol: 504
# processing time: 83.12 minutes
# Loop  72 , start wol: 511
# processing time: 83.96 minutes
# Loop  73 , start wol: 518
# processing time: 84.75 minutes
# Loop  74 , start wol: 525
# processing time: 85.49 minutes
# Loop  75 , start wol: 532
# processing time: 86.23 minutes
# Loop  76 , start wol: 539
# processing time: 86.95 minutes
# Loop  77 , start wol: 546
# processing time: 87.66 minutes
# Loop  78 , start wol: 553
# processing time: 88.37 minutes
# Loop  79 , start wol: 560
# processing time: 89.04 minutes
# Loop  80 , start wol: 567
# processing time: 89.7 minutes
# Loop  81 , start wol: 574
# processing time: 90.37 minutes
# Loop  82 , start wol: 581
# processing time: 91.04 minutes
# Loop  83 , start wol: 588
# processing time: 91.7 minutes
# Loop  84 , start wol: 595
# processing time: 92.36 minutes
# Loop  85 , start wol: 602
# processing time: 93.01 minutes
# Loop  86 , start wol: 609
# processing time: 93.68 minutes
# Loop  87 , start wol: 616
# processing time: 94.34 minutes
# Loop  88 , start wol: 623
# processing time: 95.0 minutes
# Loop  89 , start wol: 630
# processing time: 95.71 minutes
# Loop  90 , start wol: 637
# processing time: 96.42 minutes
# Loop  91 , start wol: 644
# processing time: 97.13 minutes
# Loop  92 , start wol: 651
# processing time: 97.83 minutes
# Loop  93 , start wol: 658
# processing time: 98.58 minutes
# Loop  94 , start wol: 665
# processing time: 99.33 minutes
# Loop  95 , start wol: 672
# processing time: 100.13 minutes
# Loop  96 , start wol: 679
# processing time: 100.98 minutes
# Loop  97 , start wol: 686
# processing time: 101.92 minutes
# Loop  98 , start wol: 693
# processing time: 102.94 minutes
# Loop  99 , start wol: 700
# processing time: 104.05 minutes
# Loop  100 , start wol: 707
# processing time: 105.2 minutes
# Loop  101 , start wol: 714
# processing time: 106.44 minutes
# Loop  102 , start wol: 721
# processing time: 107.77 minutes
# Loop  103 , start wol: 728
# processing time: 109.11 minutes
# Kernel complete
# processing time: 109.11 minutes

# %%
IIT_RR
# Out:
# [0.1675,
#  0.13,
#  0.095,
#  0.075,
#  0.0575,
#  0.0525,
#  0.055,
#  0.0525,
#  0.05,
#  0.0475,
#  0.045,
#  0.04,
#  0.0375,
#  0.0325,
#  0.03,
#  0.0275,
#  0.0225,
#  0.0174999999999999,
#  0.015,
#  0.01,
#  0.01,
#  0.0075,
#  0.005,
#  0.005,
#  0.005,
#  0.005,
#  0.0025,
#  0.0025,
#  0.0025,
#  0.0025,
#  0.0025,
#  0.0025,
#  0.0025,
#  0.0025,
#  0.0025,
#  0.0025,
#  0.005,
#  0.005,
#  0.005,
#  0.005,
#  0.0075,
#  0.0075,
#  0.01,
#  0.0125,
#  0.0174999999999999,
#  0.0225,
#  0.0275,
#  0.0325,
#  0.0375,
#  0.0425,
#  0.0475,
#  0.0525,
#  0.06,
#  0.0625,
#  0.0675,
#  0.0675,
#  0.07,
#  0.0675,
#  0.065,
#  0.0625,
#  0.0575,
#  0.0525,
#  0.05,
#  0.045,
#  0.04,
#  0.035,
#  0.0325,
#  0.0275,
#  0.0249999999999999,
#  0.02,
#  0.015,
#  0.0125,
#  0.01,
#  0.0075,
#  0.0075,
#  0.005,
#  0.005,
#  0.005,
#  0.0025,
#  0.0025,
#  0.0025,
#  0.0025,
#  0.0025,
#  0.0025,
#  0.0025,
#  0.0025,
#  0.0025,
#  0.0025,
#  0.005,
#  0.005,
#  0.005,
#  0.005,
#  0.0075,
#  0.0075,
#  0.01,
#  0.0125,
#  0.0174999999999999,
#  0.0225,
#  0.0275,
#  0.03,
#  0.035,
#  0.04,
#  0.0475,
#  0.0525]

# %%
len(IIT_RR) # check 104 timepoints, two years sampled weekly
# Out:
# 104

# %%
data2 = {'IIT_RR': IIT_RR}

IIT_RR_df = pd.DataFrame(data2)
IIT_RR_df.to_csv('IIT_RR_df_01-02-24.csv')

# %%
# switch off

def IIT(t, releasenumber=1, frequency=7, end=start_wol):
    for i in range(0,releasenumber,1):
        if round(t) == (end-frequency) - (frequency*i):
            return 0 #M0+F0
    else:
        return 0

# %% [markdown]
# ### SIT

# %%
SIT_df = pd.read_csv(f'{filepath}/SIT_df_01-02-24.csv')
RRsupp = list(SIT_df.loc[SIT_df['Target efficacy'] == 49, 'RRsupp value'])
RRsupp = RRsupp[0]

# %%
start_time = time.time()




RR_vec = list(RR_df.iloc[:,1])
SIT_RR = [] #capture results here
start_wol = 0
eggRR = 0
x = -1


while start_wol < 722:

    
    start_wol = start_wol+7
    x = x+1 # index for storing results
    zoo = [] # shell capturing within-loop results
    
    
    def pulseN(t, start_wol=start_wol, releasenumber=5, frequency=14):    
        for i in range(0,releasenumber,1):
            if round(t) == start_wol + (frequency*i):
                return O0
        else:
            return 0
    
    switch = 0 #0 for SIT; 1 for RIDL

    def SIT(t, releasenumber=5, frequency=7, end=start_wol):    
        for i in range(0,releasenumber,1):
            if round(t) == (end-frequency) - (frequency*i):
                return M0+F0
        else:
            return 0
    
    if eggRR == 0: # search whole RR vec
        a = 0
        b = 199
    else: # search only within range of last RR
        idx = list(RR_df.index[RR_df['eggRR'] == eggRR])
        
        if idx[0]-15 < 0: #if lower boundary crosses 0 set as 0
            a = 0
        else:
            a = idx[0]-15
        
        if idx[0]+15 > 199: #if upper boundary crosses max set as max
            b = 199
        else:
            b = idx[0]+15
        
    
    for i in RR_vec[a:b]:
        
        RR = i
        
        # run the model
        t = np.linspace(0, 1500, 1501) # Grid of time points (in days)
        y0 = O0, OW0, rOW0, OS0, L0, LW0, rLW0, LS0, P0, PW0, rPW0, PS0, M0, MW0, MS0, F0, FW0 # Init condition vector
        ret= odeint(deriv, y0, t,args=(fCI, MT, c, e, phi, alphaO, muO, AA, BB, alphaL, alphaP, muP, muM, muF, RR, RRsupp, pulseN, K, IIT, SIT, em, lv, ad, cv, switch),hmax=1)
        O, OW, rOW, OS, L, LW, rLW, LS, P, PW, rPW, PS, M, MW, MS, F, FW = ret.T

        # get output
        total = MW+FW+M+F
        prop = (MW+FW)/(MW+FW+M+F)
    
        # find fixation points
        fix = np.argwhere(prop > 0.95)
        if sum(fix) > 0:
            min_fix = min(fix)-start_wol
            min_fix = min_fix.tolist()
        else:
            min_fix = 0 #occurs if no fixation
        
        zoo.append(min_fix) #store fixation points
        
    
    # flatten list
    flat_list = []
    for sublist in zoo:
        if type(sublist) == list:
            for item in sublist:
                flat_list.append(item)
        else:
            flat_list.append(sublist)
    
    
    # only keep fix within 6 months
    sixm_list2 = [] 
    for i in flat_list:
        if (i >= 182.5) == True: #within 6 months
            i = 0
        sixm_list2.append(i)
    
    
    # convert eggRR to adultRR and store result outside of loop
    if sum(sixm_list2) > 0: 
        ind = (sixm_list2.index(max(sixm_list2)))
        eggRR = RR_vec[ind+a]
        adultRR = convert_RR(eggRR)
        SIT_RR.append(adultRR)
    else:
        eggRR = 0
        SIT_RR.append('NaN')


    
    print("Loop ",x,", start wol:", start_wol)
    current_time = time.time()
    elapsed_time = current_time - start_time
    print('processing time:',round(elapsed_time/60,2),'minutes')
    
    
    
print("Kernel complete")    
current_time = time.time()
elapsed_time = current_time - start_time
print('processing time:',round(elapsed_time/60,2),'minutes')
# Out:
# Loop  0 , start wol: 7
# processing time: 8.77 minutes
# Loop  1 , start wol: 14
# processing time: 10.11 minutes
# Loop  2 , start wol: 21
# processing time: 11.44 minutes
# Loop  3 , start wol: 28
# processing time: 12.76 minutes
# Loop  4 , start wol: 35
# processing time: 14.15 minutes
# Loop  5 , start wol: 42
# processing time: 15.49 minutes
# Loop  6 , start wol: 49
# processing time: 16.82 minutes
# Loop  7 , start wol: 56
# processing time: 18.18 minutes
# Loop  8 , start wol: 63
# processing time: 19.53 minutes
# Loop  9 , start wol: 70
# processing time: 20.86 minutes
# Loop  10 , start wol: 77
# processing time: 22.2 minutes
# Loop  11 , start wol: 84
# processing time: 23.53 minutes
# Loop  12 , start wol: 91
# processing time: 24.85 minutes
# Loop  13 , start wol: 98
# processing time: 26.17 minutes
# Loop  14 , start wol: 105
# processing time: 27.49 minutes
# Loop  15 , start wol: 112
# processing time: 28.81 minutes
# Loop  16 , start wol: 119
# processing time: 30.13 minutes
# Loop  17 , start wol: 126
# processing time: 31.44 minutes
# Loop  18 , start wol: 133
# processing time: 32.76 minutes
# Loop  19 , start wol: 140
# processing time: 34.08 minutes
# Loop  20 , start wol: 147
# processing time: 35.4 minutes
# Loop  21 , start wol: 154
# processing time: 36.72 minutes
# Loop  22 , start wol: 161
# processing time: 38.04 minutes
# Loop  23 , start wol: 168
# processing time: 39.35 minutes
# Loop  24 , start wol: 175
# processing time: 40.68 minutes
# Loop  25 , start wol: 182
# processing time: 42.0 minutes
# Loop  26 , start wol: 189
# processing time: 43.28 minutes
# Loop  27 , start wol: 196
# processing time: 44.56 minutes
# Loop  28 , start wol: 203
# processing time: 45.84 minutes
# Loop  29 , start wol: 210
# processing time: 47.12 minutes
# Loop  30 , start wol: 217
# processing time: 48.4 minutes
# Loop  31 , start wol: 224
# processing time: 49.68 minutes
# Loop  32 , start wol: 231
# processing time: 50.96 minutes
# Loop  33 , start wol: 238
# processing time: 52.24 minutes
# Loop  34 , start wol: 245
# processing time: 53.56 minutes
# Loop  35 , start wol: 252
# processing time: 54.89 minutes
# Loop  36 , start wol: 259
# processing time: 56.22 minutes
# Loop  37 , start wol: 266
# processing time: 57.54 minutes
# Loop  38 , start wol: 273
# processing time: 58.86 minutes
# Loop  39 , start wol: 280
# processing time: 60.2 minutes
# Loop  40 , start wol: 287
# processing time: 61.52 minutes
# Loop  41 , start wol: 294
# processing time: 62.85 minutes
# Loop  42 , start wol: 301
# processing time: 64.18 minutes
# Loop  43 , start wol: 308
# processing time: 65.51 minutes
# Loop  44 , start wol: 315
# processing time: 66.83 minutes
# Loop  45 , start wol: 322
# processing time: 68.18 minutes
# Loop  46 , start wol: 329
# processing time: 69.51 minutes
# Loop  47 , start wol: 336
# processing time: 70.83 minutes
# Loop  48 , start wol: 343
# processing time: 72.15 minutes
# Loop  49 , start wol: 350
# processing time: 73.47 minutes
# Loop  50 , start wol: 357
# processing time: 74.8 minutes
# Loop  51 , start wol: 364
# processing time: 76.13 minutes
# Loop  52 , start wol: 371
# processing time: 77.46 minutes
# Loop  53 , start wol: 378
# processing time: 78.78 minutes
# Loop  54 , start wol: 385
# processing time: 80.1 minutes
# Loop  55 , start wol: 392
# processing time: 81.43 minutes
# Loop  56 , start wol: 399
# processing time: 82.76 minutes
# Loop  57 , start wol: 406
# processing time: 84.08 minutes
# Loop  58 , start wol: 413
# processing time: 85.4 minutes
# Loop  59 , start wol: 420
# processing time: 86.73 minutes
# Loop  60 , start wol: 427
# processing time: 88.07 minutes
# Loop  61 , start wol: 434
# processing time: 89.39 minutes
# Loop  62 , start wol: 441
# processing time: 90.72 minutes
# Loop  63 , start wol: 448
# processing time: 92.05 minutes
# Loop  64 , start wol: 455
# processing time: 93.37 minutes
# Loop  65 , start wol: 462
# processing time: 94.7 minutes
# Loop  66 , start wol: 469
# processing time: 96.04 minutes
# Loop  67 , start wol: 476
# processing time: 97.37 minutes
# Loop  68 , start wol: 483
# processing time: 98.68 minutes
# Loop  69 , start wol: 490
# processing time: 100.0 minutes
# Loop  70 , start wol: 497
# processing time: 101.32 minutes
# Loop  71 , start wol: 504
# processing time: 102.64 minutes
# Loop  72 , start wol: 511
# processing time: 103.98 minutes
# Loop  73 , start wol: 518
# processing time: 105.31 minutes
# Loop  74 , start wol: 525
# processing time: 106.63 minutes
# Loop  75 , start wol: 532
# processing time: 107.96 minutes
# Loop  76 , start wol: 539
# processing time: 109.3 minutes
# Loop  77 , start wol: 546
# processing time: 110.62 minutes
# Loop  78 , start wol: 553
# processing time: 111.91 minutes
# Loop  79 , start wol: 560
# processing time: 113.21 minutes
# Loop  80 , start wol: 567
# processing time: 114.5 minutes
# Loop  81 , start wol: 574
# processing time: 115.79 minutes
# Loop  82 , start wol: 581
# processing time: 117.07 minutes
# Loop  83 , start wol: 588
# processing time: 118.35 minutes
# Loop  84 , start wol: 595
# processing time: 119.63 minutes
# Loop  85 , start wol: 602
# processing time: 120.91 minutes
# Loop  86 , start wol: 609
# processing time: 122.23 minutes
# Loop  87 , start wol: 616
# processing time: 123.55 minutes
# Loop  88 , start wol: 623
# processing time: 124.88 minutes
# Loop  89 , start wol: 630
# processing time: 126.2 minutes
# Loop  90 , start wol: 637
# processing time: 127.51 minutes
# Loop  91 , start wol: 644
# processing time: 128.83 minutes
# Loop  92 , start wol: 651
# processing time: 130.15 minutes
# Loop  93 , start wol: 658
# processing time: 131.48 minutes
# Loop  94 , start wol: 665
# processing time: 132.8 minutes
# Loop  95 , start wol: 672
# processing time: 134.12 minutes
# Loop  96 , start wol: 679
# processing time: 135.44 minutes
# Loop  97 , start wol: 686
# processing time: 136.76 minutes
# Loop  98 , start wol: 693
# processing time: 138.08 minutes
# Loop  99 , start wol: 700
# processing time: 139.41 minutes
# Loop  100 , start wol: 707
# processing time: 140.73 minutes
# Loop  101 , start wol: 714
# processing time: 142.07 minutes
# Loop  102 , start wol: 721
# processing time: 143.39 minutes
# Loop  103 , start wol: 728
# processing time: 144.73 minutes
# Kernel complete
# processing time: 144.73 minutes

# %%
SIT_RR
# Out:
# [0.19,
#  0.17,
#  0.1525,
#  0.1375,
#  0.1225,
#  0.115,
#  0.1125,
#  0.1075,
#  0.1025,
#  0.0975,
#  0.09,
#  0.085,
#  0.0775,
#  0.0725,
#  0.0675,
#  0.0625,
#  0.06,
#  0.055,
#  0.0525,
#  0.05,
#  0.045,
#  0.045,
#  0.0425,
#  0.04,
#  0.04,
#  0.0375,
#  0.0375,
#  0.0375,
#  0.0375,
#  0.0375,
#  0.0375,
#  0.0375,
#  0.0375,
#  0.04,
#  0.04,
#  0.0425,
#  0.045,
#  0.0475,
#  0.05,
#  0.0525,
#  0.0575,
#  0.06,
#  0.0675,
#  0.0725,
#  0.0775,
#  0.085,
#  0.0925,
#  0.1025,
#  0.11,
#  0.1175,
#  0.125,
#  0.1325,
#  0.1375,
#  0.14,
#  0.14,
#  0.1375,
#  0.135,
#  0.13,
#  0.125,
#  0.1175,
#  0.11,
#  0.1025,
#  0.095,
#  0.0875,
#  0.0825,
#  0.075,
#  0.07,
#  0.065,
#  0.06,
#  0.0575,
#  0.0525,
#  0.05,
#  0.0475,
#  0.045,
#  0.0425,
#  0.04,
#  0.04,
#  0.0375,
#  0.0375,
#  0.0375,
#  0.0375,
#  0.0375,
#  0.0375,
#  0.0375,
#  0.0375,
#  0.04,
#  0.04,
#  0.0425,
#  0.045,
#  0.045,
#  0.05,
#  0.0525,
#  0.055,
#  0.06,
#  0.065,
#  0.07,
#  0.0775,
#  0.085,
#  0.0925,
#  0.1,
#  0.11,
#  0.1175,
#  0.125,
#  0.13]

# %%
len(SIT_RR)  # check 104 timepoints, two years sampled weekly
# Out:
# 104

# %%
data3 = {'SIT_RR': SIT_RR}

SIT_RR_df = pd.DataFrame(data3)
SIT_RR_df.to_csv('SIT_RR_df_01-02-24.csv')

# %%
# switch off

switch = 0 #0 for SIT; 1 for RIDL

def SIT(t, releasenumber=5, frequency=7, end=start_wol):    
    for i in range(0,releasenumber,1):
        if round(t) == (end-frequency) - (frequency*i):
            return 0 #M0+F0
    else:
        return 0

# %% [markdown]
# ### RIDL

# %%
RIDL_df = pd.read_csv(f'{filepath}/RIDL_df.csv')
RRsupp = list(RIDL_df.loc[RIDL_df['Target efficacy'] == 45, 'RRsupp value'])
RRsupp = RRsupp[0]

# %%
start_time = time.time()




RR_vec = list(RR_df.iloc[:,1])
RIDL_RR = [] #capture results here
start_wol = 0
eggRR = 0
x = -1


while start_wol < 722:

    
    start_wol = start_wol+7
    x = x+1 # index for storing results
    zoo = [] # shell capturing within-loop results
    
    
    def pulseN(t, start_wol=start_wol, releasenumber=5, frequency=14):    
        for i in range(0,releasenumber,1):
            if round(t) == start_wol + (frequency*i):
                return O0
        else:
            return 0
    
    switch = 1 #0 for SIT; 1 for RIDL

    def SIT(t, releasenumber=5, frequency=7, end=start_wol):    
        for i in range(0,releasenumber,1):
            if round(t) == (end-frequency) - (frequency*i):
                return M0+F0
        else:
            return 0
    
    if eggRR == 0: # search whole RR vec
        a = 0
        b = 199
    else: # search only within range of last RR
        idx = list(RR_df.index[RR_df['eggRR'] == eggRR])
        
        if idx[0]-15 < 0: #if lower boundary crosses 0 set as 0
            a = 0
        else:
            a = idx[0]-15
        
        if idx[0]+15 > 199: #if upper boundary crosses max set as max
            b = 199
        else:
            b = idx[0]+15
        
    
    for i in RR_vec[a:b]:
        
        RR = i
        
        # run the model
        t = np.linspace(0, 1500, 1501) # Grid of time points (in days)
        y0 = O0, OW0, rOW0, OS0, L0, LW0, rLW0, LS0, P0, PW0, rPW0, PS0, M0, MW0, MS0, F0, FW0 # Init condition vector
        ret= odeint(deriv, y0, t,args=(fCI, MT, c, e, phi, alphaO, muO, AA, BB, alphaL, alphaP, muP, muM, muF, RR, RRsupp, pulseN, K, IIT, SIT, em, lv, ad, cv, switch),hmax=1)
        O, OW, rOW, OS, L, LW, rLW, LS, P, PW, rPW, PS, M, MW, MS, F, FW = ret.T

        # get output
        total = MW+FW+M+F
        prop = (MW+FW)/(MW+FW+M+F)
    
        # find fixation points
        fix = np.argwhere(prop > 0.95)
        if sum(fix) > 0:
            min_fix = min(fix)-start_wol
            min_fix = min_fix.tolist()
        else:
            min_fix = 0 #occurs if no fixation
        
        zoo.append(min_fix) #store fixation points
        
    
    # flatten list
    flat_list = []
    for sublist in zoo:
        if type(sublist) == list:
            for item in sublist:
                flat_list.append(item)
        else:
            flat_list.append(sublist)
    
    
    # only keep fix within 6 months
    sixm_list2 = [] 
    for i in flat_list:
        if (i >= 182.5) == True: #within 6 months
            i = 0
        sixm_list2.append(i)
    
    
    # convert eggRR to adultRR and store result outside of loop
    if sum(sixm_list2) > 0: 
        ind = (sixm_list2.index(max(sixm_list2)))
        eggRR = RR_vec[ind+a]
        adultRR = convert_RR(eggRR)
        RIDL_RR.append(adultRR)
    else:
        eggRR = 0
        RIDL_RR.append('NaN')


    
    print("Loop ",x,", start wol:", start_wol)
    current_time = time.time()
    elapsed_time = current_time - start_time
    print('processing time:',round(elapsed_time/60,2),'minutes')
    
    
    
print("Kernel complete")    
current_time = time.time()
elapsed_time = current_time - start_time
print('processing time:',round(elapsed_time/60,2),'minutes')
# Out:
# Loop  0 , start wol: 7
# processing time: 8.62 minutes
# Loop  1 , start wol: 14
# processing time: 9.92 minutes
# Loop  2 , start wol: 21
# processing time: 11.2 minutes
# Loop  3 , start wol: 28
# processing time: 12.48 minutes
# Loop  4 , start wol: 35
# processing time: 13.76 minutes
# Loop  5 , start wol: 42
# processing time: 15.04 minutes
# Loop  6 , start wol: 49
# processing time: 16.33 minutes
# Loop  7 , start wol: 56
# processing time: 17.63 minutes
# Loop  8 , start wol: 63
# processing time: 18.93 minutes
# Loop  9 , start wol: 70
# processing time: 20.24 minutes
# Loop  10 , start wol: 77
# processing time: 21.54 minutes
# Loop  11 , start wol: 84
# processing time: 22.84 minutes
# Loop  12 , start wol: 91
# processing time: 24.15 minutes
# Loop  13 , start wol: 98
# processing time: 25.45 minutes
# Loop  14 , start wol: 105
# processing time: 26.74 minutes
# Loop  15 , start wol: 112
# processing time: 28.04 minutes
# Loop  16 , start wol: 119
# processing time: 29.34 minutes
# Loop  17 , start wol: 126
# processing time: 30.64 minutes
# Loop  18 , start wol: 133
# processing time: 31.94 minutes
# Loop  19 , start wol: 140
# processing time: 33.23 minutes
# Loop  20 , start wol: 147
# processing time: 34.53 minutes
# Loop  21 , start wol: 154
# processing time: 35.79 minutes
# Loop  22 , start wol: 161
# processing time: 37.05 minutes
# Loop  23 , start wol: 168
# processing time: 38.28 minutes
# Loop  24 , start wol: 175
# processing time: 39.46 minutes
# Loop  25 , start wol: 182
# processing time: 40.63 minutes
# Loop  26 , start wol: 189
# processing time: 41.77 minutes
# Loop  27 , start wol: 196
# processing time: 42.9 minutes
# Loop  28 , start wol: 203
# processing time: 44.04 minutes
# Loop  29 , start wol: 210
# processing time: 45.12 minutes
# Loop  30 , start wol: 217
# processing time: 46.21 minutes
# Loop  31 , start wol: 224
# processing time: 47.31 minutes
# Loop  32 , start wol: 231
# processing time: 48.4 minutes
# Loop  33 , start wol: 238
# processing time: 49.53 minutes
# Loop  34 , start wol: 245
# processing time: 50.66 minutes
# Loop  35 , start wol: 252
# processing time: 51.8 minutes
# Loop  36 , start wol: 259
# processing time: 52.97 minutes
# Loop  37 , start wol: 266
# processing time: 54.16 minutes
# Loop  38 , start wol: 273
# processing time: 55.39 minutes
# Loop  39 , start wol: 280
# processing time: 56.66 minutes
# Loop  40 , start wol: 287
# processing time: 57.98 minutes
# Loop  41 , start wol: 294
# processing time: 59.3 minutes
# Loop  42 , start wol: 301
# processing time: 60.62 minutes
# Loop  43 , start wol: 308
# processing time: 61.94 minutes
# Loop  44 , start wol: 315
# processing time: 63.27 minutes
# Loop  45 , start wol: 322
# processing time: 64.59 minutes
# Loop  46 , start wol: 329
# processing time: 65.92 minutes
# Loop  47 , start wol: 336
# processing time: 67.24 minutes
# Loop  48 , start wol: 343
# processing time: 68.56 minutes
# Loop  49 , start wol: 350
# processing time: 69.89 minutes
# Loop  50 , start wol: 357
# processing time: 71.22 minutes
# Loop  51 , start wol: 364
# processing time: 72.52 minutes
# Loop  52 , start wol: 371
# processing time: 73.82 minutes
# Loop  53 , start wol: 378
# processing time: 75.13 minutes
# Loop  54 , start wol: 385
# processing time: 76.45 minutes
# Loop  55 , start wol: 392
# processing time: 77.76 minutes
# Loop  56 , start wol: 399
# processing time: 79.08 minutes
# Loop  57 , start wol: 406
# processing time: 80.4 minutes
# Loop  58 , start wol: 413
# processing time: 81.71 minutes
# Loop  59 , start wol: 420
# processing time: 83.02 minutes
# Loop  60 , start wol: 427
# processing time: 84.33 minutes
# Loop  61 , start wol: 434
# processing time: 85.64 minutes
# Loop  62 , start wol: 441
# processing time: 86.95 minutes
# Loop  63 , start wol: 448
# processing time: 88.26 minutes
# Loop  64 , start wol: 455
# processing time: 89.56 minutes
# Loop  65 , start wol: 462
# processing time: 90.84 minutes
# Loop  66 , start wol: 469
# processing time: 92.14 minutes
# Loop  67 , start wol: 476
# processing time: 93.43 minutes
# Loop  68 , start wol: 483
# processing time: 94.73 minutes
# Loop  69 , start wol: 490
# processing time: 96.03 minutes
# Loop  70 , start wol: 497
# processing time: 97.34 minutes
# Loop  71 , start wol: 504
# processing time: 98.64 minutes
# Loop  72 , start wol: 511
# processing time: 99.94 minutes
# Loop  73 , start wol: 518
# processing time: 101.24 minutes
# Loop  74 , start wol: 525
# processing time: 102.5 minutes
# Loop  75 , start wol: 532
# processing time: 103.71 minutes
# Loop  76 , start wol: 539
# processing time: 104.88 minutes
# Loop  77 , start wol: 546
# processing time: 106.05 minutes
# Loop  78 , start wol: 553
# processing time: 107.18 minutes
# Loop  79 , start wol: 560
# processing time: 108.31 minutes
# Loop  80 , start wol: 567
# processing time: 109.44 minutes
# Loop  81 , start wol: 574
# processing time: 110.52 minutes
# Loop  82 , start wol: 581
# processing time: 111.61 minutes
# Loop  83 , start wol: 588
# processing time: 112.69 minutes
# Loop  84 , start wol: 595
# processing time: 113.78 minutes
# Loop  85 , start wol: 602
# processing time: 114.9 minutes
# Loop  86 , start wol: 609
# processing time: 116.03 minutes
# Loop  87 , start wol: 616
# processing time: 117.15 minutes
# Loop  88 , start wol: 623
# processing time: 118.33 minutes
# Loop  89 , start wol: 630
# processing time: 119.5 minutes
# Loop  90 , start wol: 637
# processing time: 120.71 minutes
# Loop  91 , start wol: 644
# processing time: 121.97 minutes
# Loop  92 , start wol: 651
# processing time: 123.27 minutes
# Loop  93 , start wol: 658
# processing time: 124.57 minutes
# Loop  94 , start wol: 665
# processing time: 125.87 minutes
# Loop  95 , start wol: 672
# processing time: 127.17 minutes
# Loop  96 , start wol: 679
# processing time: 128.49 minutes
# Loop  97 , start wol: 686
# processing time: 129.8 minutes
# Loop  98 , start wol: 693
# processing time: 131.12 minutes
# Loop  99 , start wol: 700
# processing time: 132.45 minutes
# Loop  100 , start wol: 707
# processing time: 133.78 minutes
# Loop  101 , start wol: 714
# processing time: 135.11 minutes
# Loop  102 , start wol: 721
# processing time: 136.44 minutes
# Loop  103 , start wol: 728
# processing time: 137.77 minutes
# Kernel complete
# processing time: 137.77 minutes

# %%
RIDL_RR
# Out:
# [0.19,
#  0.1675,
#  0.145,
#  0.1275,
#  0.11,
#  0.1025,
#  0.1,
#  0.0975,
#  0.0925,
#  0.0875,
#  0.0825,
#  0.0775,
#  0.07,
#  0.065,
#  0.06,
#  0.055,
#  0.0525,
#  0.0475,
#  0.045,
#  0.0425,
#  0.0375,
#  0.0375,
#  0.035,
#  0.0325,
#  0.0325,
#  0.03,
#  0.03,
#  0.03,
#  0.0275,
#  0.0275,
#  0.0275,
#  0.0275,
#  0.03,
#  0.03,
#  0.03,
#  0.0325,
#  0.0325,
#  0.035,
#  0.0375,
#  0.04,
#  0.0425,
#  0.0475,
#  0.0525,
#  0.0575,
#  0.0625,
#  0.0675,
#  0.075,
#  0.0825,
#  0.0925,
#  0.1,
#  0.1075,
#  0.1125,
#  0.1175,
#  0.1225,
#  0.125,
#  0.125,
#  0.1225,
#  0.1175,
#  0.1125,
#  0.1075,
#  0.1,
#  0.095,
#  0.0875,
#  0.08,
#  0.075,
#  0.0675,
#  0.0625,
#  0.0575,
#  0.0525,
#  0.05,
#  0.045,
#  0.0425,
#  0.04,
#  0.0375,
#  0.035,
#  0.0325,
#  0.0325,
#  0.03,
#  0.03,
#  0.03,
#  0.0275,
#  0.0275,
#  0.0275,
#  0.0275,
#  0.03,
#  0.03,
#  0.03,
#  0.0325,
#  0.0325,
#  0.035,
#  0.0375,
#  0.04,
#  0.0425,
#  0.0475,
#  0.05,
#  0.055,
#  0.0625,
#  0.0675,
#  0.075,
#  0.0825,
#  0.09,
#  0.0975,
#  0.105,
#  0.1125]

# %%
len(RIDL_RR) # check 104 timepoints, two years sampled weekly
# Out:
# 104

# %%
data4 = {'RIDL_RR': RIDL_RR}

RIDL_RR_df = pd.DataFrame(data4)
RIDL_RR_df.to_csv('RIDL_RR_df.csv')
RIDL_RR_df
# Out:
#      RIDL_RR
# 0     0.1900
# 1     0.1675
# 2     0.1450
# 3     0.1275
# 4     0.1100
# ..       ...
# 99    0.0825
# 100   0.0900
# 101   0.0975
# 102   0.1050
# 103   0.1125
#
# [104 rows x 1 columns]

# %%
# switch off

switch = 1 #0 for SIT; 1 for RIDL

def SIT(t, releasenumber=5, frequency=7, end=start_wol):    
    for i in range(0,releasenumber,1):
        if round(t) == (end-frequency) - (frequency*i):
            return 0 #M0+F0
    else:
        return 0

# %% [markdown]
# ### Environmental Management

# %%
EM_df = pd.read_csv(f'{filepath}/EM_df.csv')
em_eff = list(EM_df.loc[EM_df['Target efficacy'] == 47.4, 'Efficacy parameter'])
em_eff = em_eff[0]

# %%
start_time = time.time()




RR_vec = list(RR_df.iloc[:,1])
EM_RR = [] #capture results here
start_wol = 0
eggRR = 0
x = -1


while start_wol < 722:

    
    start_wol = start_wol+7
    x = x+1 # index for storing results
    zoo = [] # shell capturing within-loop results
    
    
    def pulseN(t, start_wol=start_wol, releasenumber=5, frequency=14):    
        for i in range(0,releasenumber,1):
            if round(t) == start_wol + (frequency*i):
                return O0
        else:
            return 0
    

    def em(t):
        if round(t) < start_wol-(5*7):     #start
            return 1
        elif round(t) > start_wol:    #stop releases
            return 1
        else:
            return em_eff
    
    
    if eggRR == 0: # search whole RR vec
        a = 0
        b = 199
    else: # search only within range of last RR
        idx = list(RR_df.index[RR_df['eggRR'] == eggRR])
        
        if idx[0]-15 < 0: #if lower boundary crosses 0 set as 0
            a = 0
        else:
            a = idx[0]-15
        
        if idx[0]+15 > 199: #if upper boundary crosses max set as max
            b = 199
        else:
            b = idx[0]+15
        
    
    for i in RR_vec[a:b]:
        
        RR = i
        
        # run the model
        t = np.linspace(0, 1500, 1501) # Grid of time points (in days)
        y0 = O0, OW0, rOW0, OS0, L0, LW0, rLW0, LS0, P0, PW0, rPW0, PS0, M0, MW0, MS0, F0, FW0 # Init condition vector
        ret= odeint(deriv, y0, t,args=(fCI, MT, c, e, phi, alphaO, muO, AA, BB, alphaL, alphaP, muP, muM, muF, RR, RRsupp, pulseN, K, IIT, SIT, em, lv, ad, cv, switch),hmax=1)
        O, OW, rOW, OS, L, LW, rLW, LS, P, PW, rPW, PS, M, MW, MS, F, FW = ret.T

        # get output
        total = MW+FW+M+F
        prop = (MW+FW)/(MW+FW+M+F)
    
        # find fixation points
        fix = np.argwhere(prop > 0.95)
        if sum(fix) > 0:
            min_fix = min(fix)-start_wol
            min_fix = min_fix.tolist()
        else:
            min_fix = 0 #occurs if no fixation
        
        zoo.append(min_fix) #store fixation points
        
    
    # flatten list
    flat_list = []
    for sublist in zoo:
        if type(sublist) == list:
            for item in sublist:
                flat_list.append(item)
        else:
            flat_list.append(sublist)
    
    
    # only keep fix within 6 months
    sixm_list2 = [] 
    for i in flat_list:
        if (i >= 182.5) == True: #within 6 months
            i = 0
        sixm_list2.append(i)
    
    
    # convert eggRR to adultRR and store result outside of loop
    if sum(sixm_list2) > 0: 
        ind = (sixm_list2.index(max(sixm_list2)))
        eggRR = RR_vec[ind+a]
        adultRR = convert_RR(eggRR)
        EM_RR.append(adultRR)
    else:
        eggRR = 0
        EM_RR.append('NaN')


    
    print("Loop ",x,", start wol:", start_wol)
    current_time = time.time()
    elapsed_time = current_time - start_time
    print('processing time:',round(elapsed_time/60,2),'minutes')
    
    
    
print("Kernel complete")    
current_time = time.time()
elapsed_time = current_time - start_time
print('processing time:',round(elapsed_time/60,2),'minutes')
# Out:
# Loop  0 , start wol: 7
# processing time: 8.67 minutes
# Loop  1 , start wol: 14
# processing time: 9.98 minutes
# Loop  2 , start wol: 21
# processing time: 11.3 minutes
# Loop  3 , start wol: 28
# processing time: 12.6 minutes
# Loop  4 , start wol: 35
# processing time: 13.92 minutes
# Loop  5 , start wol: 42
# processing time: 15.23 minutes
# Loop  6 , start wol: 49
# processing time: 16.54 minutes
# Loop  7 , start wol: 56
# processing time: 17.85 minutes
# Loop  8 , start wol: 63
# processing time: 19.15 minutes
# Loop  9 , start wol: 70
# processing time: 20.45 minutes
# Loop  10 , start wol: 77
# processing time: 21.76 minutes
# Loop  11 , start wol: 84
# processing time: 23.06 minutes
# Loop  12 , start wol: 91
# processing time: 24.36 minutes
# Loop  13 , start wol: 98
# processing time: 25.67 minutes
# Loop  14 , start wol: 105
# processing time: 26.99 minutes
# Loop  15 , start wol: 112
# processing time: 28.3 minutes
# Loop  16 , start wol: 119
# processing time: 29.61 minutes
# Loop  17 , start wol: 126
# processing time: 30.91 minutes
# Loop  18 , start wol: 133
# processing time: 32.22 minutes
# Loop  19 , start wol: 140
# processing time: 33.54 minutes
# Loop  20 , start wol: 147
# processing time: 34.85 minutes
# Loop  21 , start wol: 154
# processing time: 36.16 minutes
# Loop  22 , start wol: 161
# processing time: 37.47 minutes
# Loop  23 , start wol: 168
# processing time: 38.78 minutes
# Loop  24 , start wol: 175
# processing time: 40.09 minutes
# Loop  25 , start wol: 182
# processing time: 41.4 minutes
# Loop  26 , start wol: 189
# processing time: 42.72 minutes
# Loop  27 , start wol: 196
# processing time: 44.02 minutes
# Loop  28 , start wol: 203
# processing time: 45.33 minutes
# Loop  29 , start wol: 210
# processing time: 46.65 minutes
# Loop  30 , start wol: 217
# processing time: 47.96 minutes
# Loop  31 , start wol: 224
# processing time: 49.28 minutes
# Loop  32 , start wol: 231
# processing time: 50.6 minutes
# Loop  33 , start wol: 238
# processing time: 51.91 minutes
# Loop  34 , start wol: 245
# processing time: 53.21 minutes
# Loop  35 , start wol: 252
# processing time: 54.53 minutes
# Loop  36 , start wol: 259
# processing time: 55.85 minutes
# Loop  37 , start wol: 266
# processing time: 57.16 minutes
# Loop  38 , start wol: 273
# processing time: 58.47 minutes
# Loop  39 , start wol: 280
# processing time: 59.79 minutes
# Loop  40 , start wol: 287
# processing time: 61.11 minutes
# Loop  41 , start wol: 294
# processing time: 62.43 minutes
# Loop  42 , start wol: 301
# processing time: 63.74 minutes
# Loop  43 , start wol: 308
# processing time: 65.04 minutes
# Loop  44 , start wol: 315
# processing time: 66.35 minutes
# Loop  45 , start wol: 322
# processing time: 67.65 minutes
# Loop  46 , start wol: 329
# processing time: 68.94 minutes
# Loop  47 , start wol: 336
# processing time: 70.24 minutes
# Loop  48 , start wol: 343
# processing time: 71.55 minutes
# Loop  49 , start wol: 350
# processing time: 72.84 minutes
# Loop  50 , start wol: 357
# processing time: 74.15 minutes
# Loop  51 , start wol: 364
# processing time: 75.45 minutes
# Loop  52 , start wol: 371
# processing time: 76.75 minutes
# Loop  53 , start wol: 378
# processing time: 78.05 minutes
# Loop  54 , start wol: 385
# processing time: 79.36 minutes
# Loop  55 , start wol: 392
# processing time: 80.66 minutes
# Loop  56 , start wol: 399
# processing time: 81.96 minutes
# Loop  57 , start wol: 406
# processing time: 83.26 minutes
# Loop  58 , start wol: 413
# processing time: 84.56 minutes
# Loop  59 , start wol: 420
# processing time: 85.86 minutes
# Loop  60 , start wol: 427
# processing time: 87.15 minutes
# Loop  61 , start wol: 434
# processing time: 88.46 minutes
# Loop  62 , start wol: 441
# processing time: 89.76 minutes
# Loop  63 , start wol: 448
# processing time: 91.05 minutes
# Loop  64 , start wol: 455
# processing time: 92.36 minutes
# Loop  65 , start wol: 462
# processing time: 93.65 minutes
# Loop  66 , start wol: 469
# processing time: 94.95 minutes
# Loop  67 , start wol: 476
# processing time: 96.25 minutes
# Loop  68 , start wol: 483
# processing time: 97.55 minutes
# Loop  69 , start wol: 490
# processing time: 98.85 minutes
# Loop  70 , start wol: 497
# processing time: 100.16 minutes
# Loop  71 , start wol: 504
# processing time: 101.48 minutes
# Loop  72 , start wol: 511
# processing time: 102.8 minutes
# Loop  73 , start wol: 518
# processing time: 104.13 minutes
# Loop  74 , start wol: 525
# processing time: 105.46 minutes
# Loop  75 , start wol: 532
# processing time: 106.78 minutes
# Loop  76 , start wol: 539
# processing time: 108.1 minutes
# Loop  77 , start wol: 546
# processing time: 109.42 minutes
# Loop  78 , start wol: 553
# processing time: 110.73 minutes
# Loop  79 , start wol: 560
# processing time: 112.05 minutes
# Loop  80 , start wol: 567
# processing time: 113.36 minutes
# Loop  81 , start wol: 574
# processing time: 114.68 minutes
# Loop  82 , start wol: 581
# processing time: 116.0 minutes
# Loop  83 , start wol: 588
# processing time: 117.32 minutes
# Loop  84 , start wol: 595
# processing time: 118.63 minutes
# Loop  85 , start wol: 602
# processing time: 119.94 minutes
# Loop  86 , start wol: 609
# processing time: 121.26 minutes
# Loop  87 , start wol: 616
# processing time: 122.57 minutes
# Loop  88 , start wol: 623
# processing time: 123.89 minutes
# Loop  89 , start wol: 630
# processing time: 125.2 minutes
# Loop  90 , start wol: 637
# processing time: 126.52 minutes
# Loop  91 , start wol: 644
# processing time: 127.84 minutes
# Loop  92 , start wol: 651
# processing time: 129.18 minutes
# Loop  93 , start wol: 658
# processing time: 130.5 minutes
# Loop  94 , start wol: 665
# processing time: 131.82 minutes
# Loop  95 , start wol: 672
# processing time: 133.14 minutes
# Loop  96 , start wol: 679
# processing time: 134.45 minutes
# Loop  97 , start wol: 686
# processing time: 135.76 minutes
# Loop  98 , start wol: 693
# processing time: 137.07 minutes
# Loop  99 , start wol: 700
# processing time: 138.39 minutes
# Loop  100 , start wol: 707
# processing time: 139.7 minutes
# Loop  101 , start wol: 714
# processing time: 141.03 minutes
# Loop  102 , start wol: 721
# processing time: 142.34 minutes
# Loop  103 , start wol: 728
# processing time: 143.66 minutes
# Kernel complete
# processing time: 143.66 minutes

# %%
EM_RR
# Out:
# [0.195,
#  0.1875,
#  0.18,
#  0.17,
#  0.16,
#  0.155,
#  0.1475,
#  0.1425,
#  0.135,
#  0.1275,
#  0.12,
#  0.1125,
#  0.105,
#  0.1,
#  0.095,
#  0.09,
#  0.085,
#  0.0825,
#  0.0775,
#  0.075,
#  0.0725,
#  0.0725,
#  0.07,
#  0.0675,
#  0.0675,
#  0.0675,
#  0.0675,
#  0.0675,
#  0.0675,
#  0.0675,
#  0.07,
#  0.07,
#  0.0725,
#  0.075,
#  0.0775,
#  0.08,
#  0.085,
#  0.0875,
#  0.0925,
#  0.0975,
#  0.105,
#  0.11,
#  0.1175,
#  0.125,
#  0.135,
#  0.1425,
#  0.1525,
#  0.16,
#  0.17,
#  0.1775,
#  0.1825,
#  0.1875,
#  0.1875,
#  0.1875,
#  0.185,
#  0.18,
#  0.1725,
#  0.165,
#  0.1575,
#  0.1475,
#  0.14,
#  0.13,
#  0.1225,
#  0.115,
#  0.1075,
#  0.1025,
#  0.0975,
#  0.0925,
#  0.0875,
#  0.0825,
#  0.08,
#  0.0775,
#  0.075,
#  0.0725,
#  0.07,
#  0.0675,
#  0.0675,
#  0.0675,
#  0.0675,
#  0.0675,
#  0.0675,
#  0.0675,
#  0.07,
#  0.07,
#  0.0725,
#  0.075,
#  0.0775,
#  0.08,
#  0.0825,
#  0.0875,
#  0.0925,
#  0.0975,
#  0.1025,
#  0.11,
#  0.1175,
#  0.125,
#  0.1325,
#  0.1425,
#  0.15,
#  0.16,
#  0.1675,
#  0.175,
#  0.1825,
#  0.1875]

# %%
len(EM_RR) # check 104 timepoints, two years sampled weekly
# Out:
# 104

# %%
data5 = {'EM_RR': EM_RR}

EM_RR_df = pd.DataFrame(data5)
EM_RR_df.to_csv('EM_RR_df.csv')
EM_RR_df
# Out:
#       EM_RR
# 0    0.1950
# 1    0.1875
# 2    0.1800
# 3    0.1700
# 4    0.1600
# ..      ...
# 99   0.1600
# 100  0.1675
# 101  0.1750
# 102  0.1825
# 103  0.1875
#
# [104 rows x 1 columns]

# %%
#switch off

em_eff = 1

# %% [markdown]
# ### Larvicide

# %%
LV_df = pd.read_csv(f'{filepath}/LV_df.csv')
lv_eff = list(LV_df.loc[LV_df['Target efficacy'] == 45, 'Efficacy parameter'])
lv_eff = lv_eff[0]

# %%
start_time = time.time()




RR_vec = list(RR_df.iloc[:,1])
LV_RR = [] #capture results here
start_wol = 0
eggRR = 0
x = -1


while start_wol < 722:

    
    start_wol = start_wol+7
    x = x+1 # index for storing results
    zoo = [] # shell capturing within-loop results
    
    
    def pulseN(t, start_wol=start_wol, releasenumber=5, frequency=14):    
        for i in range(0,releasenumber,1):
            if round(t) == start_wol + (frequency*i):
                return O0
        else:
            return 0
    

    def lv(t):
        if round(t) < start_wol-(5*7):     #start
            return 1
        elif round(t) > start_wol:    #stop releases
            return 1
        else:
            return lv_eff
    
    
    if eggRR == 0: # search whole RR vec
        a = 0
        b = 199
    else: # search only within range of last RR
        idx = list(RR_df.index[RR_df['eggRR'] == eggRR])
        
        if idx[0]-15 < 0: #if lower boundary crosses 0 set as 0
            a = 0
        else:
            a = idx[0]-15
        
        if idx[0]+15 > 199: #if upper boundary crosses max set as max
            b = 199
        else:
            b = idx[0]+15
        
    
    for i in RR_vec[a:b]:
        
        RR = i
        
        # run the model
        t = np.linspace(0, 1500, 1501) # Grid of time points (in days)
        y0 = O0, OW0, rOW0, OS0, L0, LW0, rLW0, LS0, P0, PW0, rPW0, PS0, M0, MW0, MS0, F0, FW0 # Init condition vector
        ret= odeint(deriv, y0, t,args=(fCI, MT, c, e, phi, alphaO, muO, AA, BB, alphaL, alphaP, muP, muM, muF, RR, RRsupp, pulseN, K, IIT, SIT, em, lv, ad, cv, switch),hmax=1)
        O, OW, rOW, OS, L, LW, rLW, LS, P, PW, rPW, PS, M, MW, MS, F, FW = ret.T

        # get output
        total = MW+FW+M+F
        prop = (MW+FW)/(MW+FW+M+F)
    
        # find fixation points
        fix = np.argwhere(prop > 0.95)
        if sum(fix) > 0:
            min_fix = min(fix)-start_wol
            min_fix = min_fix.tolist()
        else:
            min_fix = 0 #occurs if no fixation
        
        zoo.append(min_fix) #store fixation points
        
    
    # flatten list
    flat_list = []
    for sublist in zoo:
        if type(sublist) == list:
            for item in sublist:
                flat_list.append(item)
        else:
            flat_list.append(sublist)
    
    
    # only keep fix within 6 months
    sixm_list2 = [] 
    for i in flat_list:
        if (i >= 182.5) == True: #within 6 months
            i = 0
        sixm_list2.append(i)
    
    
    # convert eggRR to adultRR and store result outside of loop
    if sum(sixm_list2) > 0: 
        ind = (sixm_list2.index(max(sixm_list2)))
        eggRR = RR_vec[ind+a]
        adultRR = convert_RR(eggRR)
        LV_RR.append(adultRR)
    else:
        eggRR = 0
        LV_RR.append('NaN')


    
    print("Loop ",x,", start wol:", start_wol)
    current_time = time.time()
    elapsed_time = current_time - start_time
    print('processing time:',round(elapsed_time/60,2),'minutes')
    
    
    
print("Kernel complete")    
current_time = time.time()
elapsed_time = current_time - start_time
print('processing time:',round(elapsed_time/60,2),'minutes')
# Out:
# Loop  0 , start wol: 7
# processing time: 8.81 minutes
# Loop  1 , start wol: 14
# processing time: 10.14 minutes
# Loop  2 , start wol: 21
# processing time: 11.48 minutes
# Loop  3 , start wol: 28
# processing time: 12.81 minutes
# Loop  4 , start wol: 35
# processing time: 14.14 minutes
# Loop  5 , start wol: 42
# processing time: 15.47 minutes
# Loop  6 , start wol: 49
# processing time: 16.8 minutes
# Loop  7 , start wol: 56
# processing time: 18.12 minutes
# Loop  8 , start wol: 63
# processing time: 19.45 minutes
# Loop  9 , start wol: 70
# processing time: 20.78 minutes
# Loop  10 , start wol: 77
# processing time: 22.11 minutes
# Loop  11 , start wol: 84
# processing time: 23.44 minutes
# Loop  12 , start wol: 91
# processing time: 24.76 minutes
# Loop  13 , start wol: 98
# processing time: 26.08 minutes
# Loop  14 , start wol: 105
# processing time: 27.41 minutes
# Loop  15 , start wol: 112
# processing time: 28.74 minutes
# Loop  16 , start wol: 119
# processing time: 30.07 minutes
# Loop  17 , start wol: 126
# processing time: 31.4 minutes
# Loop  18 , start wol: 133
# processing time: 32.74 minutes
# Loop  19 , start wol: 140
# processing time: 34.07 minutes
# Loop  20 , start wol: 147
# processing time: 35.39 minutes
# Loop  21 , start wol: 154
# processing time: 36.72 minutes
# Loop  22 , start wol: 161
# processing time: 38.04 minutes
# Loop  23 , start wol: 168
# processing time: 39.36 minutes
# Loop  24 , start wol: 175
# processing time: 40.69 minutes
# Loop  25 , start wol: 182
# processing time: 42.02 minutes
# Loop  26 , start wol: 189
# processing time: 43.33 minutes
# Loop  27 , start wol: 196
# processing time: 44.65 minutes
# Loop  28 , start wol: 203
# processing time: 45.97 minutes
# Loop  29 , start wol: 210
# processing time: 47.29 minutes
# Loop  30 , start wol: 217
# processing time: 48.62 minutes
# Loop  31 , start wol: 224
# processing time: 49.94 minutes
# Loop  32 , start wol: 231
# processing time: 51.26 minutes
# Loop  33 , start wol: 238
# processing time: 52.58 minutes
# Loop  34 , start wol: 245
# processing time: 53.9 minutes
# Loop  35 , start wol: 252
# processing time: 55.22 minutes
# Loop  36 , start wol: 259
# processing time: 56.53 minutes
# Loop  37 , start wol: 266
# processing time: 57.84 minutes
# Loop  38 , start wol: 273
# processing time: 59.15 minutes
# Loop  39 , start wol: 280
# processing time: 60.47 minutes
# Loop  40 , start wol: 287
# processing time: 61.77 minutes
# Loop  41 , start wol: 294
# processing time: 63.1 minutes
# Loop  42 , start wol: 301
# processing time: 64.43 minutes
# Loop  43 , start wol: 308
# processing time: 65.75 minutes
# Loop  44 , start wol: 315
# processing time: 67.06 minutes
# Loop  45 , start wol: 322
# processing time: 68.4 minutes
# Loop  46 , start wol: 329
# processing time: 69.71 minutes
# Loop  47 , start wol: 336
# processing time: 71.04 minutes
# Loop  48 , start wol: 343
# processing time: 72.36 minutes
# Loop  49 , start wol: 350
# processing time: 73.67 minutes
# Loop  50 , start wol: 357
# processing time: 74.99 minutes
# Loop  51 , start wol: 364
# processing time: 76.32 minutes
# Loop  52 , start wol: 371
# processing time: 77.63 minutes
# Loop  53 , start wol: 378
# processing time: 78.94 minutes
# Loop  54 , start wol: 385
# processing time: 80.26 minutes
# Loop  55 , start wol: 392
# processing time: 81.58 minutes
# Loop  56 , start wol: 399
# processing time: 82.9 minutes
# Loop  57 , start wol: 406
# processing time: 84.21 minutes
# Loop  58 , start wol: 413
# processing time: 85.53 minutes
# Loop  59 , start wol: 420
# processing time: 86.85 minutes
# Loop  60 , start wol: 427
# processing time: 88.17 minutes
# Loop  61 , start wol: 434
# processing time: 89.49 minutes
# Loop  62 , start wol: 441
# processing time: 90.8 minutes
# Loop  63 , start wol: 448
# processing time: 92.11 minutes
# Loop  64 , start wol: 455
# processing time: 93.43 minutes
# Loop  65 , start wol: 462
# processing time: 94.75 minutes
# Loop  66 , start wol: 469
# processing time: 96.06 minutes
# Loop  67 , start wol: 476
# processing time: 97.38 minutes
# Loop  68 , start wol: 483
# processing time: 98.7 minutes
# Loop  69 , start wol: 490
# processing time: 100.02 minutes
# Loop  70 , start wol: 497
# processing time: 101.34 minutes
# Loop  71 , start wol: 504
# processing time: 102.66 minutes
# Loop  72 , start wol: 511
# processing time: 103.98 minutes
# Loop  73 , start wol: 518
# processing time: 105.29 minutes
# Loop  74 , start wol: 525
# processing time: 106.6 minutes
# Loop  75 , start wol: 532
# processing time: 107.91 minutes
# Loop  76 , start wol: 539
# processing time: 109.21 minutes
# Loop  77 , start wol: 546
# processing time: 110.52 minutes
# Loop  78 , start wol: 553
# processing time: 111.83 minutes
# Loop  79 , start wol: 560
# processing time: 113.14 minutes
# Loop  80 , start wol: 567
# processing time: 114.45 minutes
# Loop  81 , start wol: 574
# processing time: 115.75 minutes
# Loop  82 , start wol: 581
# processing time: 117.06 minutes
# Loop  83 , start wol: 588
# processing time: 118.36 minutes
# Loop  84 , start wol: 595
# processing time: 119.67 minutes
# Loop  85 , start wol: 602
# processing time: 120.97 minutes
# Loop  86 , start wol: 609
# processing time: 122.27 minutes
# Loop  87 , start wol: 616
# processing time: 123.57 minutes
# Loop  88 , start wol: 623
# processing time: 124.87 minutes
# Loop  89 , start wol: 630
# processing time: 126.17 minutes
# Loop  90 , start wol: 637
# processing time: 127.47 minutes
# Loop  91 , start wol: 644
# processing time: 128.77 minutes
# Loop  92 , start wol: 651
# processing time: 130.08 minutes
# Loop  93 , start wol: 658
# processing time: 131.38 minutes
# Loop  94 , start wol: 665
# processing time: 132.68 minutes
# Loop  95 , start wol: 672
# processing time: 133.99 minutes
# Loop  96 , start wol: 679
# processing time: 135.3 minutes
# Loop  97 , start wol: 686
# processing time: 136.61 minutes
# Loop  98 , start wol: 693
# processing time: 137.91 minutes
# Loop  99 , start wol: 700
# processing time: 139.21 minutes
# Loop  100 , start wol: 707
# processing time: 140.52 minutes
# Loop  101 , start wol: 714
# processing time: 141.83 minutes
# Loop  102 , start wol: 721
# processing time: 143.15 minutes
# Loop  103 , start wol: 728
# processing time: 144.46 minutes
# Kernel complete
# processing time: 144.46 minutes

# %%
LV_RR
# Out:
# [0.195,
#  0.19,
#  0.185,
#  0.1775,
#  0.1675,
#  0.1625,
#  0.155,
#  0.1475,
#  0.14,
#  0.13,
#  0.1225,
#  0.115,
#  0.11,
#  0.1025,
#  0.0975,
#  0.0925,
#  0.0875,
#  0.085,
#  0.08,
#  0.0775,
#  0.075,
#  0.0725,
#  0.0725,
#  0.07,
#  0.07,
#  0.07,
#  0.0675,
#  0.07,
#  0.07,
#  0.07,
#  0.0725,
#  0.0725,
#  0.075,
#  0.0775,
#  0.08,
#  0.085,
#  0.0875,
#  0.0925,
#  0.0975,
#  0.1025,
#  0.1075,
#  0.115,
#  0.1225,
#  0.1325,
#  0.14,
#  0.15,
#  0.16,
#  0.17,
#  0.1775,
#  0.185,
#  0.1925,
#  0.1975,
#  0.1975,
#  0.195,
#  0.1925,
#  0.1875,
#  0.18,
#  0.1725,
#  0.1625,
#  0.1525,
#  0.145,
#  0.135,
#  0.1275,
#  0.12,
#  0.1125,
#  0.105,
#  0.1,
#  0.095,
#  0.09,
#  0.085,
#  0.0825,
#  0.0775,
#  0.0775,
#  0.075,
#  0.0725,
#  0.07,
#  0.07,
#  0.07,
#  0.07,
#  0.07,
#  0.07,
#  0.07,
#  0.0725,
#  0.0725,
#  0.075,
#  0.0775,
#  0.08,
#  0.0825,
#  0.0875,
#  0.0925,
#  0.095,
#  0.1025,
#  0.1075,
#  0.115,
#  0.1225,
#  0.13,
#  0.14,
#  0.15,
#  0.1575,
#  0.1675,
#  0.1775,
#  0.185,
#  0.1925,
#  0.195]

# %%
len(LV_RR) # check 104 timepoints, two years sampled weekly
# Out:
# 104

# %%
data6 = {'LV_RR': LV_RR}

LV_RR_df = pd.DataFrame(data6)
LV_RR_df.to_csv('LV_RR_df.csv')
LV_RR_df
# Out:
#       LV_RR
# 0    0.1950
# 1    0.1900
# 2    0.1850
# 3    0.1775
# 4    0.1675
# ..      ...
# 99   0.1675
# 100  0.1775
# 101  0.1850
# 102  0.1925
# 103  0.1950
#
# [104 rows x 1 columns]

# %%
# switch off
lv_eff = 1

# %% [markdown]
# ### Adulticide

# %%
AD_df = pd.read_csv(f'{filepath}/AD_df.csv')
ad_eff = list(AD_df.loc[AD_df['Target efficacy'] == 94, 'Efficacy parameter'])
ad_eff = ad_eff[0]
cv = list(AD_df.loc[AD_df['Target efficacy'] == 94, 'Coverage value'])
cv = cv[0]

# %%
# switch on

h = [] #needed to set adulticide pulses
for i in range(-4, 1, 1):
    h.append((start_wol-7) + (7*i))

def ad(t):    
#    ad_eff = 0
    if round(t) < h[0]:
        return 0
    elif round(t) > h[0]+0.01 and round(t) < h[1]:
        return 0
    elif round(t) > h[1]+0.01 and round(t) < h[2]:
        return 0
    elif round(t) > h[2]+0.01 and round(t) < h[3]:
        return 0
    elif round(t) > h[3]+0.01 and round(t) < h[4]:
        return 0
    elif round(t) > h[4]+0.01:
        return 0
    else:
        return ad_eff

# %%
start_time = time.time()




RR_vec = list(RR_df.iloc[:,1])
AD_RR = [] #capture results here
start_wol = 0
eggRR = 0
x = -1


while start_wol < 722:

    
    start_wol = start_wol+7
    x = x+1 # index for storing results
    zoo = [] # shell capturing within-loop results
    
    
    def pulseN(t, start_wol=start_wol, releasenumber=5, frequency=14):    
        for i in range(0,releasenumber,1):
            if round(t) == start_wol + (frequency*i):
                return O0
        else:
            return 0
    

    h = [] #needed to set adulticide pulses
    for i in range(-4, 1, 1):
        h.append((start_wol-7) + (7*i))
    
    
    if eggRR == 0: # search whole RR vec
        a = 0
        b = 199
    else: # search only within range of last RR
        idx = list(RR_df.index[RR_df['eggRR'] == eggRR])
        
        if idx[0]-15 < 0: #if lower boundary crosses 0 set as 0
            a = 0
        else:
            a = idx[0]-15
        
        if idx[0]+15 > 199: #if upper boundary crosses max set as max
            b = 199
        else:
            b = idx[0]+15
        
    
    for i in RR_vec[a:b]:
        
        RR = i
        
        # run the model
        t = np.linspace(0, 1500, 1501) # Grid of time points (in days)
        y0 = O0, OW0, rOW0, OS0, L0, LW0, rLW0, LS0, P0, PW0, rPW0, PS0, M0, MW0, MS0, F0, FW0 # Init condition vector
        ret= odeint(deriv, y0, t,args=(fCI, MT, c, e, phi, alphaO, muO, AA, BB, alphaL, alphaP, muP, muM, muF, RR, RRsupp, pulseN, K, IIT, SIT, em, lv, ad, cv, switch),hmax=1)
        O, OW, rOW, OS, L, LW, rLW, LS, P, PW, rPW, PS, M, MW, MS, F, FW = ret.T

        # get output
        total = MW+FW+M+F
        prop = (MW+FW)/(MW+FW+M+F)
    
        # find fixation points
        fix = np.argwhere(prop > 0.95)
        if sum(fix) > 0:
            min_fix = min(fix)-start_wol
            min_fix = min_fix.tolist()
        else:
            min_fix = 0 #occurs if no fixation
        
        zoo.append(min_fix) #store fixation points
        
    
    # flatten list
    flat_list = []
    for sublist in zoo:
        if type(sublist) == list:
            for item in sublist:
                flat_list.append(item)
        else:
            flat_list.append(sublist)
    
    
    # only keep fix within 6 months
    sixm_list2 = [] 
    for i in flat_list:
        if (i >= 182.5) == True: #within 6 months
            i = 0
        sixm_list2.append(i)
    
    
    # convert eggRR to adultRR and store result outside of loop
    if sum(sixm_list2) > 0: 
        ind = (sixm_list2.index(max(sixm_list2)))
        eggRR = RR_vec[ind+a]
        adultRR = convert_RR(eggRR)
        AD_RR.append(adultRR)
    else:
        eggRR = 0
        AD_RR.append('NaN')


    
    print("Loop ",x,", start wol:", start_wol)
    current_time = time.time()
    elapsed_time = current_time - start_time
    print('processing time:',round(elapsed_time/60,2),'minutes')
    
    
    
print("Kernel complete")    
current_time = time.time()
elapsed_time = current_time - start_time
print('processing time:',round(elapsed_time/60,2),'minutes')
# Out:
# Loop  0 , start wol: 7
# processing time: 10.7 minutes
# Loop  1 , start wol: 14
# processing time: 12.31 minutes
# Loop  2 , start wol: 21
# processing time: 13.96 minutes
# Loop  3 , start wol: 28
# processing time: 15.61 minutes
# Loop  4 , start wol: 35
# processing time: 17.24 minutes
# Loop  5 , start wol: 42
# processing time: 18.88 minutes
# Loop  6 , start wol: 49
# processing time: 20.51 minutes
# Loop  7 , start wol: 56
# processing time: 22.14 minutes
# Loop  8 , start wol: 63
# processing time: 23.77 minutes
# Loop  9 , start wol: 70
# processing time: 25.39 minutes
# Loop  10 , start wol: 77
# processing time: 27.02 minutes
# Loop  11 , start wol: 84
# processing time: 28.65 minutes
# Loop  12 , start wol: 91
# processing time: 30.27 minutes
# Loop  13 , start wol: 98
# processing time: 31.88 minutes
# Loop  14 , start wol: 105
# processing time: 33.48 minutes
# Loop  15 , start wol: 112
# processing time: 35.08 minutes
# Loop  16 , start wol: 119
# processing time: 36.69 minutes
# Loop  17 , start wol: 126
# processing time: 38.28 minutes
# Loop  18 , start wol: 133
# processing time: 39.87 minutes
# Loop  19 , start wol: 140
# processing time: 41.47 minutes
# Loop  20 , start wol: 147
# processing time: 43.07 minutes
# Loop  21 , start wol: 154
# processing time: 44.67 minutes
# Loop  22 , start wol: 161
# processing time: 46.27 minutes
# Loop  23 , start wol: 168
# processing time: 47.86 minutes
# Loop  24 , start wol: 175
# processing time: 49.45 minutes
# Loop  25 , start wol: 182
# processing time: 51.03 minutes
# Loop  26 , start wol: 189
# processing time: 52.62 minutes
# Loop  27 , start wol: 196
# processing time: 54.21 minutes
# Loop  28 , start wol: 203
# processing time: 55.78 minutes
# Loop  29 , start wol: 210
# processing time: 57.36 minutes
# Loop  30 , start wol: 217
# processing time: 58.93 minutes
# Loop  31 , start wol: 224
# processing time: 60.51 minutes
# Loop  32 , start wol: 231
# processing time: 62.08 minutes
# Loop  33 , start wol: 238
# processing time: 63.64 minutes
# Loop  34 , start wol: 245
# processing time: 65.2 minutes
# Loop  35 , start wol: 252
# processing time: 66.76 minutes
# Loop  36 , start wol: 259
# processing time: 68.31 minutes
# Loop  37 , start wol: 266
# processing time: 69.86 minutes
# Loop  38 , start wol: 273
# processing time: 71.41 minutes
# Loop  39 , start wol: 280
# processing time: 72.96 minutes
# Loop  40 , start wol: 287
# processing time: 74.51 minutes
# Loop  41 , start wol: 294
# processing time: 76.06 minutes
# Loop  42 , start wol: 301
# processing time: 77.61 minutes
# Loop  43 , start wol: 308
# processing time: 79.15 minutes
# Loop  44 , start wol: 315
# processing time: 80.69 minutes
# Loop  45 , start wol: 322
# processing time: 82.23 minutes
# Loop  46 , start wol: 329
# processing time: 83.77 minutes
# Loop  47 , start wol: 336
# processing time: 85.3 minutes
# Loop  48 , start wol: 343
# processing time: 86.83 minutes
# Loop  49 , start wol: 350
# processing time: 88.38 minutes
# Loop  50 , start wol: 357
# processing time: 89.92 minutes
# Loop  51 , start wol: 364
# processing time: 91.46 minutes
# Loop  52 , start wol: 371
# processing time: 93.0 minutes
# Loop  53 , start wol: 378
# processing time: 94.53 minutes
# Loop  54 , start wol: 385
# processing time: 96.06 minutes
# Loop  55 , start wol: 392
# processing time: 97.59 minutes
# Loop  56 , start wol: 399
# processing time: 99.12 minutes
# Loop  57 , start wol: 406
# processing time: 100.64 minutes
# Loop  58 , start wol: 413
# processing time: 102.17 minutes
# Loop  59 , start wol: 420
# processing time: 103.7 minutes
# Loop  60 , start wol: 427
# processing time: 105.22 minutes
# Loop  61 , start wol: 434
# processing time: 106.74 minutes
# Loop  62 , start wol: 441
# processing time: 108.26 minutes
# Loop  63 , start wol: 448
# processing time: 109.76 minutes
# Loop  64 , start wol: 455
# processing time: 111.26 minutes
# Loop  65 , start wol: 462
# processing time: 112.76 minutes
# Loop  66 , start wol: 469
# processing time: 114.25 minutes
# Loop  67 , start wol: 476
# processing time: 115.74 minutes
# Loop  68 , start wol: 483
# processing time: 117.23 minutes
# Loop  69 , start wol: 490
# processing time: 118.73 minutes
# Loop  70 , start wol: 497
# processing time: 120.21 minutes
# Loop  71 , start wol: 504
# processing time: 121.69 minutes
# Loop  72 , start wol: 511
# processing time: 123.18 minutes
# Loop  73 , start wol: 518
# processing time: 124.66 minutes
# Loop  74 , start wol: 525
# processing time: 126.14 minutes
# Loop  75 , start wol: 532
# processing time: 127.62 minutes
# Loop  76 , start wol: 539
# processing time: 129.1 minutes
# Loop  77 , start wol: 546
# processing time: 130.58 minutes
# Loop  78 , start wol: 553
# processing time: 132.06 minutes
# Loop  79 , start wol: 560
# processing time: 133.53 minutes
# Loop  80 , start wol: 567
# processing time: 134.99 minutes
# Loop  81 , start wol: 574
# processing time: 136.45 minutes
# Loop  82 , start wol: 581
# processing time: 137.92 minutes
# Loop  83 , start wol: 588
# processing time: 139.38 minutes
# Loop  84 , start wol: 595
# processing time: 140.84 minutes
# Loop  85 , start wol: 602
# processing time: 142.29 minutes
# Loop  86 , start wol: 609
# processing time: 143.75 minutes
# Loop  87 , start wol: 616
# processing time: 145.2 minutes
# Loop  88 , start wol: 623
# processing time: 146.65 minutes
# Loop  89 , start wol: 630
# processing time: 148.11 minutes
# Loop  90 , start wol: 637
# processing time: 149.55 minutes
# Loop  91 , start wol: 644
# processing time: 151.0 minutes
# Loop  92 , start wol: 651
# processing time: 152.44 minutes
# Loop  93 , start wol: 658
# processing time: 153.89 minutes
# Loop  94 , start wol: 665
# processing time: 155.32 minutes
# Loop  95 , start wol: 672
# processing time: 156.76 minutes
# Loop  96 , start wol: 679
# processing time: 158.2 minutes
# Loop  97 , start wol: 686
# processing time: 159.65 minutes
# Loop  98 , start wol: 693
# processing time: 161.08 minutes
# Loop  99 , start wol: 700
# processing time: 162.51 minutes
# Loop  100 , start wol: 707
# processing time: 163.94 minutes
# Loop  101 , start wol: 714
# processing time: 165.37 minutes
# Loop  102 , start wol: 721
# processing time: 166.79 minutes
# Loop  103 , start wol: 728
# processing time: 168.22 minutes
# Kernel complete
# processing time: 168.22 minutes

# %%
AD_RR
# Out:
# [0.1925,
#  0.175,
#  0.1575,
#  0.145,
#  0.1325,
#  0.125,
#  0.1175,
#  0.11,
#  0.105,
#  0.0975,
#  0.09,
#  0.085,
#  0.08,
#  0.075,
#  0.07,
#  0.0675,
#  0.065,
#  0.06,
#  0.06,
#  0.0575,
#  0.055,
#  0.0525,
#  0.0525,
#  0.0525,
#  0.05,
#  0.05,
#  0.05,
#  0.05,
#  0.0525,
#  0.0525,
#  0.0525,
#  0.055,
#  0.0575,
#  0.0575,
#  0.06,
#  0.0625,
#  0.065,
#  0.07,
#  0.0725,
#  0.0775,
#  0.0825,
#  0.0875,
#  0.0925,
#  0.1,
#  0.105,
#  0.1125,
#  0.12,
#  0.1275,
#  0.135,
#  0.1425,
#  0.1475,
#  0.15,
#  0.1525,
#  0.15,
#  0.1475,
#  0.1425,
#  0.1375,
#  0.13,
#  0.1225,
#  0.115,
#  0.1075,
#  0.1,
#  0.0925,
#  0.0875,
#  0.0825,
#  0.0775,
#  0.0725,
#  0.0675,
#  0.065,
#  0.0625,
#  0.06,
#  0.0575,
#  0.055,
#  0.0525,
#  0.0525,
#  0.0525,
#  0.05,
#  0.05,
#  0.05,
#  0.05,
#  0.0525,
#  0.0525,
#  0.0525,
#  0.055,
#  0.055,
#  0.0575,
#  0.06,
#  0.0625,
#  0.065,
#  0.0675,
#  0.0725,
#  0.0775,
#  0.08,
#  0.0875,
#  0.0925,
#  0.0975,
#  0.105,
#  0.1125,
#  0.12,
#  0.1275,
#  0.135,
#  0.1425,
#  0.1475,
#  0.15]

# %%
len(AD_RR) # check 104 timepoints, two years sampled weekly
# Out:
# 104

# %%
data7 = {'AD_RR': AD_RR}

AD_RR_df = pd.DataFrame(data7)
AD_RR_df.to_csv('AD_RR_df.csv')
AD_RR_df
# Out:
#       AD_RR
# 0    0.1925
# 1    0.1750
# 2    0.1575
# 3    0.1450
# 4    0.1325
# ..      ...
# 99   0.1275
# 100  0.1350
# 101  0.1425
# 102  0.1475
# 103  0.1500
#
# [104 rows x 1 columns]

# %%
# switch off

h = [] #needed to set adulticide pulses
for i in range(-4, 1, 1):
    h.append((start_wol-7) + (7*i))

def ad(t):    
    ad_eff = 0
    if round(t) < h[0]:
        return 0
    elif round(t) > h[0]+0.01 and round(t) < h[1]:
        return 0
    elif round(t) > h[1]+0.01 and round(t) < h[2]:
        return 0
    elif round(t) > h[2]+0.01 and round(t) < h[3]:
        return 0
    elif round(t) > h[3]+0.01 and round(t) < h[4]:
        return 0
    elif round(t) > h[4]+0.01:
        return 0
    else:
        return ad_eff

# %% [markdown]
# ### 2.b. Data formatting: minimum Wolbachia RR relative to no suppression for fixation within 6 months

# %%
data = {'NoSupp': nosupp_RR,
        'RIDL': RIDL_RR,
        'SIT': SIT_RR,
        'IIT': IIT_RR,
        'EM': EM_RR,
        'LV': LV_RR,
        'AD': AD_RR}

season_df = pd.DataFrame(data)
season_df.to_csv('season_df.csv')

# %% [markdown]
# #### To run if plotting without running script all-through:

# %%
### If using season_df (not updated for 01-02-24)

#season_df = pd.read_csv(f'{filepath}/season_df.csv')

# %%
#season_df
# Out:
#      NoSupp    RIDL     SIT     IIT      EM      LV      AD
# 0    0.2075  0.1900  0.1925  0.1750  0.1950  0.1950  0.1925
# 1    0.2100  0.1675  0.1750  0.1375  0.1875  0.1900  0.1750
# 2    0.2100  0.1450  0.1600  0.1100  0.1800  0.1850  0.1575
# 3    0.2075  0.1275  0.1450  0.0875  0.1700  0.1775  0.1450
# 4    0.2000  0.1100  0.1300  0.0725  0.1600  0.1675  0.1325
# ..      ...     ...     ...     ...     ...     ...     ...
# 99   0.2025  0.0825  0.1100  0.0425  0.1600  0.1675  0.1275
# 100  0.2150  0.0900  0.1175  0.0475  0.1675  0.1775  0.1350
# 101  0.2250  0.0975  0.1275  0.0550  0.1750  0.1850  0.1425
# 102  0.2300  0.1050  0.1350  0.0600  0.1825  0.1925  0.1475
# 103  0.2350  0.1125  0.1400  0.0675  0.1875  0.1950  0.1500
#
# [104 rows x 7 columns]

# %%
#nosupp_vec = list(season_df.iloc[:,0])
#RIDL_vec = list(season_df.iloc[:,1])
#SIT_vec = list(season_df.iloc[:,2])
#IIT_vec = list(season_df.iloc[:,3])
#EM_vec = list(season_df.iloc[:,4])
#LV_vec = list(season_df.iloc[:,5])
#AD_vec = list(season_df.iloc[:,6])

# %%
#RIDL_vec_norm = list(season_df.iloc[:,1]/season_df.iloc[:,0])
#SIT_vec_norm = list(season_df.iloc[:,2]/season_df.iloc[:,0])
#IIT_vec_norm = list(season_df.iloc[:,3]/season_df.iloc[:,0])
#EM_vec_norm = list(season_df.iloc[:,4]/season_df.iloc[:,0])
#LV_vec_norm = list(season_df.iloc[:,5]/season_df.iloc[:,0])
#AD_vec_norm = list(season_df.iloc[:,6]/season_df.iloc[:,0])

# %%
### If using individual df (updated on 01-02-24)

nosupp_RR_df = pd.read_csv(f'{filepath}/nosupp_RR_df.csv')
RIDL_RR_df = pd.read_csv(f'{filepath}/RIDL_RR_df.csv')
SIT_RR_df = pd.read_csv(f'{filepath}/SIT_RR_df_01-02-24.csv')
IIT_RR_df = pd.read_csv(f'{filepath}/IIT_RR_df_01-02-24.csv')
EM_RR_df = pd.read_csv(f'{filepath}/EM_RR_df.csv')
LV_RR_df = pd.read_csv(f'{filepath}/LV_RR_df.csv')
AD_RR_df = pd.read_csv(f'{filepath}/AD_RR_df.csv')

# %%
nosupp_vec = list(nosupp_RR_df.iloc[:,1])
RIDL_vec = list(RIDL_RR_df.iloc[:,1])
SIT_vec = list(SIT_RR_df.iloc[:,1])
IIT_vec = list(IIT_RR_df.iloc[:,1])
EM_vec = list(EM_RR_df.iloc[:,1])
LV_vec = list(LV_RR_df.iloc[:,1])
AD_vec = list(AD_RR_df.iloc[:,1])

# %%
RIDL_vec_norm = list(RIDL_RR_df.iloc[:,1]/nosupp_RR_df.iloc[:,1])
SIT_vec_norm = list(SIT_RR_df.iloc[:,1]/nosupp_RR_df.iloc[:,1])
IIT_vec_norm = list(IIT_RR_df.iloc[:,1]/nosupp_RR_df.iloc[:,1])
EM_vec_norm = list(EM_RR_df.iloc[:,1]/nosupp_RR_df.iloc[:,1])
LV_vec_norm = list(LV_RR_df.iloc[:,1]/nosupp_RR_df.iloc[:,1])
AD_vec_norm = list(AD_RR_df.iloc[:,1]/nosupp_RR_df.iloc[:,1])

# %% [markdown]
# ### 2.c. Plot results

# %%
#ABSOLUTE VALUES

Bobo = np.genfromtxt(fname="Rio.txt") # import precipitation data
Bobo2 = sm.nonparametric.lowess(Bobo[:,1], Bobo[:,0], frac=0.8/3) # smooth the curve
Bobo3 = Bobo2[:,1] #cut down the middle for a nice year loop
week = range(7,365*2,7)
month_pre = Bobo2[:,0]
month = [7]
for i in month_pre[:23]:
    month.append((i*30)+7)

t1 = week #[200,250,300,350,400,450,500,550] #week # weekly time points
t2 = month #Bobo2[:,0]*30 #Bobo4*30 # monthly time points
data0 = Bobo3 # precipitation values
data_nosupp = nosupp_vec
data1 = RIDL_vec
data2 = SIT_vec
data3 = IIT_vec
data4 = EM_vec
data5 = LV_vec
data6 = AD_vec

fig, ax1 = plt.subplots(figsize=(12, 8))
ax1.set_xlabel('Time (days)')
ax1.set_ylabel('RR')
ax1.set_ylim(0,0.3)
ax1.plot(t1, data_nosupp, color='black', linestyle = 'dashed')
ax1.plot(t1, data1, color='red') #RIDL
ax1.plot(t1, data2, color='green') #SIT
ax1.plot(t1, data3, color='purple') #IIT
ax1.plot(t1, data4, color='blue') #EM
ax1.plot(t1, data5, color='orange') #LV
ax1.plot(t1, data6, color='black') #AD

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Precipitation', color='cornflowerblue')
ax2.plot(t2, data0, color='cornflowerblue')

fig.tight_layout()
plt.show()

# %%
#ABSOLUTE VALUES - year slice down the middle

Bobo = np.genfromtxt(fname="Rio.txt") # import precipitation data
Bobo2 = sm.nonparametric.lowess(Bobo[:,1], Bobo[:,0], frac=0.8/3) # smooth the curve
Bobo3 = Bobo2[:,1] #cut down the middle for a nice year loop
week = range(7,365*2,7)
#month_pre = Bobo2[:,0]
#month = [7]
#for i in month_pre[:23]:
#    month.append((i*30)+7)
month = [15.5,29.5,74.5,105,135.5,166,196.5,227.5,258,288.5,319,349.5,
         380.5,410,439.5,470,500.5,531,561.5,592.5,623,653.5,684,714.5]

t1 = week #[200,250,300,350,400,450,500,550] #week # weekly time points
t2 = month #Bobo2[:,0]*30 #Bobo4*30 # monthly time points
data0 = Bobo3 # precipitation values
data_nosupp = nosupp_vec
data1 = RIDL_vec
data2 = SIT_vec
data3 = IIT_vec
data4 = EM_vec
data5 = LV_vec
data6 = AD_vec

fig, ax1 = plt.subplots(figsize=(12,8))
ax1.set_xlabel('Time (days)', size=16)
ax1.set_ylabel('Absolute $\it{Wolbachia}$ release ratio', size=16)
ax1.set_ylim(0, 0.3)
ax1.plot(t1, data_nosupp, color='grey', label="No suppression")
ax1.plot(t1, data1, color='red', label="1gSLT") #RIDL
ax1.plot(t1, data2, color='green', label="SIT") #SIT
ax1.plot(t1, data3, color='purple', label="Male $\it{Wolbachia}$\nrelease") #IIT
ax1.plot(t1, data4, color='cornflowerblue', label="Environmental\nmanagement") #EM
ax1.plot(t1, data5, color='orange', label="Larvicide") #LV
ax1.plot(t1, data6, color='black', label="Adulticide") #AD
ax1.set_xticks([200,250,300,350,400,450,500,550],[0,50,100,150,200,250,300,350])
ax1.set_xlim(200,565)
ax1.set_ylim(0,0.25)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Precipitation (mm)', color='blue', size=16)
ax2.set_ylim(0,4.5)
ax2.plot(t2, data0, color='blue', linestyle = 'dashed', label="Precipitation")

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

fig.tight_layout()

#plt.savefig('Figure6_01-02-24.jpeg', bbox_inches='tight', dpi = 600)

# %%
#NORMALISED - relative to no suppression

Bobo = np.genfromtxt(fname="Rio.txt") # import precipitation data
Bobo2 = sm.nonparametric.lowess(Bobo[:,1], Bobo[:,0], frac=0.8/3) # smooth the curve
Bobo3 = Bobo2[:,1]#[5:18] #cut down the middle for a nice year loop
#Bobo4 = Bobo2[:,0][0:12] #month numbers
#Bobo4 = np.insert(Bobo4, 0, 0)
#week = range(1,365,7)
#month = range(1,13)

week = range(7, 365*2,7)
#month_pre = Bobo2[:,0]
#month = [7]
#for i in month_pre[:23]:
#    month.append((i*30)+7)
month = [15.5,29.5,74.5,105,135.5,166,196.5,227.5,258,288.5,319,349.5,
         380.5,410,439.5,470,500.5,531,561.5,592.5,623,653.5,684,714.5]


t1 = week #[200,250,300,350,400,450,500,550] #week # weekly time points
t2 = Bobo2[:,0]*30 #Bobo4*30 # monthly time points
data0 = Bobo3 # precipitation values
data1 = RIDL_vec_norm
data2 = SIT_vec_norm
data3 = IIT_vec_norm
data4 = EM_vec_norm
data5 = LV_vec_norm
data6 = AD_vec_norm

fig, ax1 = plt.subplots(figsize = (12,8))
ax1.set_xlabel('Time (days)', size=16)
ax1.set_ylabel('Wolbachia RR\nrelative to no suppression', size=16)
ax1.set_ylim(0,1)
ax1.plot(t1, data1, color='red', label="1gSLT") #RIDL
ax1.plot(t1, data2, color='green', label="SIT") #SIT
ax1.plot(t1, data3, color='purple', label="Male $\it{Wolbachia}$\nrelease") #IIT
ax1.plot(t1, data4, color='cornflowerblue', label="Environmental\nmanagement") #EM
ax1.plot(t1, data5, color='orange', label="Larvicide") #LV
ax1.plot(t1, data6, color='black', label="Adulticide") #AD
ax1.set_xticks([200,250,300,350,400,450,500,550],[0,50,100,150,200,250,300,350])
ax1.set_xlim(200,565)
ax1.set_ylim(0.5,1)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Precipitation', color='blue', size=16)
ax2.set_ylim(0,4.5)
ax2.plot(t2, data0, color='blue')

ax1.legend(loc='upper right')

fig.tight_layout()

# %% [markdown]
# ### 2.d. Calculate result values

# %%
# % improvement of IIT RR compared to no suppression RR at optimal timing
100-((min(season_df.iloc[:,0])/min(season_df.iloc[:,3])))
# Out:
# 83.5

# %%
# % improvement of no suppression RR from least to most optimal timing
(min(season_df.iloc[:,0])/max(season_df.iloc[:,0]))*100
# Out:
# 34.73684210526316

# %%
# % improvement of no suppression RR at optimal timing compared to average timing
avg = (min(season_df.iloc[:,0])+max(season_df.iloc[:,0]))/2
(min(season_df.iloc[:,0])/avg)*100
# Out:
# 51.5625
